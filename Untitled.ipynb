# %%
#to extract the source content (including html tags) from a website.
import requests
page = requests.get("https://en.wikipedia.org/wiki/Web_mining")
print(page.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Web mining - Wikipedia</title>
# <script>document.documentElement.className=document.documentElement.className.replace(/(^|\s)client-nojs(\s|$)/,"$1client-js$2");RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Web_mining","wgTitle":"Web mining","wgCurRevisionId":904363144,"wgRevisionId":904363144,"wgArticleId":797887,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles needing cleanup from June 2009","All pages needing cleanup","Cleanup tagged articles without a reason field from June 2009","Wikipedia pages needing cleanup from June 2009","Articles to be expanded from June 2015","All articles to be expanded","Articles using small message boxes","Articles lacking in-text citations from September 2009","All articles lacking in-text citations","Web analytics","Data mining","World Wide Web"],"wgBreakFrames":!1,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",
# ""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Web_mining","wgRelevantArticleId":797887,"wgRequestId":"XT9WrApAAD4AAFQL4aQAAABS","wgCSPNonce":!1,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgPoweredByHHVM":!0,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia",
# "wgWikibaseItemId":"Q785337","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.gadget.charinsert-styles":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.toc.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","ext.3d.styles":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.startup","mediawiki.page.ready","mediawiki.toc","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips",
# "ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@0tffind",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});</script>
# <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.3d.styles%7Cext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.skinning.interface%7Cmediawiki.toc.styles%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.gadget.charinsert-styles&amp;only=styles&amp;skin=vector"/>
# <link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.34.0-wmf.15"/>
# <meta name="referrer" content="origin"/>
# <meta name="referrer" content="origin-when-crossorigin"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Web_mining"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Web_mining&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Web_mining&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="license" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Web_mining"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# <!--[if lt IE 9]><script src="/w/resources/lib/html5shiv/html5shiv.js"></script><![endif]-->
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Web_mining rootpage-Web_mining skin-vector action-view">
# <div id="mw-page-base" class="noprint"></div>
# <div id="mw-head-base" class="noprint"></div>
# <div id="content" class="mw-body" role="main">
# 	<a id="top"></a>
# 	<div id="siteNotice" class="mw-body-content"><!-- CentralNotice --></div>
# 	<div class="mw-indicators mw-body-content">
# </div>
#
# 	<h1 id="firstHeading" class="firstHeading" lang="en">Web mining</h1>
#
# 	<div id="bodyContent" class="mw-body-content">
# 		<div id="siteSub" class="noprint">From Wikipedia, the free encyclopedia</div>
# 		<div id="contentSub"></div>
#
#
#
# 		<div id="jump-to-nav"></div>
# 		<a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# 		<a class="mw-jump-link" href="#p-search">Jump to search</a>
# 		<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><div class="mw-parser-output"><table class="box-Cleanup plainlinks metadata ambox ambox-style ambox-Cleanup" role="presentation"><tbody><tr><td class="mbox-image"><div style="width:52px"><img alt="" src="//upload.wikimedia.org/wikipedia/en/thumb/f/f2/Edit-clear.svg/40px-Edit-clear.svg.png" decoding="async" width="40" height="40" srcset="//upload.wikimedia.org/wikipedia/en/thumb/f/f2/Edit-clear.svg/60px-Edit-clear.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/f/f2/Edit-clear.svg/80px-Edit-clear.svg.png 2x" data-file-width="48" data-file-height="48" /></div></td><td class="mbox-text"><div class="mbox-text-span">This article may <b>require <a href="/wiki/Wikipedia:Cleanup" title="Wikipedia:Cleanup">cleanup</a></b> to meet Wikipedia's <a href="/wiki/Wikipedia:Manual_of_Style" title="Wikipedia:Manual of Style">quality standards</a>.<span class="hide-when-compact"> No <a href="/wiki/Template:Cleanup/doc" title="Template:Cleanup/doc">cleanup reason</a> has been specified. Please help <a class="external text" href="//en.wikipedia.org/w/index.php?title=Web_mining&amp;action=edit">improve this article</a> if you can.</span>  <small class="date-container"><i>(<span class="date">June 2009</span>)</i></small><small class="hide-when-compact"><i> (<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></div></td></tr></tbody></table>
# <p><b>Web mining</b> is the application of <a href="/wiki/Data_mining" title="Data mining">data mining</a> techniques to discover patterns from the <a href="/wiki/World_Wide_Web" title="World Wide Web">World Wide Web</a>. As the name proposes, this is information gathered by mining the web. It makes utilization of automated apparatuses to reveal and extricate data from servers and web2 reports, and it permits organizations to get to both organized and unstructured information from browser activities, server logs, website and link structure, page content and different sources.
# </p><p>The goal of Web structure mining is to generate structural summary about the Web site and Web page. Technically, Web content mining mainly focuses on the structure of inner-document, while Web structure mining tries to discover the link structure of the hyperlinks at the inter-document level. Based on the topology of the hyperlinks, Web structure mining will categorize the Web pages and generate the information, such as the similarity and relationship between different Web sites.
# </p><p>Web structure mining can also have another direction -- discovering the structure of Web document itself. This type of structure mining can be used to reveal the structure (schema) of Web pages, this would be good for navigation purpose and make it possible to compare/integrate Web page schemes. This type of structure mining will facilitate introducing database techniques for accessing information in Web pages by providing a reference schema.
# </p>
# <div id="toc" class="toc"><input type="checkbox" role="button" id="toctogglecheckbox" class="toctogglecheckbox" style="display:none" /><div class="toctitle" lang="en" dir="ltr"><h2>Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Web_mining_types"><span class="tocnumber">1</span> <span class="toctext">Web mining types</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Web_usage_mining"><span class="tocnumber">2</span> <span class="toctext">Web usage mining</span></a>
# <ul>
# <li class="toclevel-2 tocsection-3"><a href="#Pros"><span class="tocnumber">2.1</span> <span class="toctext">Pros</span></a></li>
# <li class="toclevel-2 tocsection-4"><a href="#Cons"><span class="tocnumber">2.2</span> <span class="toctext">Cons</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-5"><a href="#Web_structure_mining"><span class="tocnumber">3</span> <span class="toctext">Web structure mining</span></a></li>
# <li class="toclevel-1 tocsection-6"><a href="#Web_content_mining"><span class="tocnumber">4</span> <span class="toctext">Web content mining</span></a>
# <ul>
# <li class="toclevel-2 tocsection-7"><a href="#Web_content_mining_in_foreign_languages"><span class="tocnumber">4.1</span> <span class="toctext">Web content mining in foreign languages</span></a>
# <ul>
# <li class="toclevel-3 tocsection-8"><a href="#Chinese"><span class="tocnumber">4.1.1</span> <span class="toctext">Chinese</span></a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-9"><a href="#See_also"><span class="tocnumber">5</span> <span class="toctext">See also</span></a></li>
# <li class="toclevel-1 tocsection-10"><a href="#References"><span class="tocnumber">6</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-11"><a href="#Resources"><span class="tocnumber">7</span> <span class="toctext">Resources</span></a>
# <ul>
# <li class="toclevel-2 tocsection-12"><a href="#External_links"><span class="tocnumber">7.1</span> <span class="toctext">External links</span></a></li>
# <li class="toclevel-2 tocsection-13"><a href="#Books"><span class="tocnumber">7.2</span> <span class="toctext">Books</span></a></li>
# <li class="toclevel-2 tocsection-14"><a href="#Bibliographic_references"><span class="tocnumber">7.3</span> <span class="toctext">Bibliographic references</span></a></li>
# </ul>
# </li>
# </ul>
# </div>
#
# <h2><span class="mw-headline" id="Web_mining_types">Web mining types</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=1" title="Edit section: Web mining types">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Web mining can be divided into three different types – <b>Web usage mining</b>, <b>Web content mining</b> and <b>Web structure mining</b>.
# </p>
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a href="/wiki/File:The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining(English_version).png" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining%28English_version%29.png/220px-The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining%28English_version%29.png" decoding="async" width="220" height="161" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining%28English_version%29.png/330px-The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining%28English_version%29.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6c/The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining%28English_version%29.png/440px-The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining%28English_version%29.png 2x" data-file-width="977" data-file-height="715" /></a>  <div class="thumbcaption"><div class="magnify"><a href="/wiki/File:The_general_relationship_between_the_categories_of_Web_Mining_and_objectives_of_Data_Mining(English_version).png" class="internal" title="Enlarge"></a></div>The general relationship between the categories of Web Mining and objectives of Data Mining</div></div></div>
# <table class="wikitable">
# <caption><span id="Comparison">Comparison</span> of web mining types<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">&#91;1&#93;</a></sup>
# </caption>
# <tbody><tr>
# <th>
# </th>
# <th colspan="2">Web content Mining
# </th>
# <th rowspan="2">Web structure mining
# </th>
# <th rowspan="2">Web usage mining
# </th></tr>
# <tr>
# <th>
# </th>
# <th>IR view
# </th>
# <th>DB view
# </th></tr>
# <tr>
# <th>View of data
# </th>
# <td>
# <ul><li>Unstructured</li>
# <li>Structured</li></ul>
# </td>
# <td>
# <ul><li>Semi-structured</li>
# <li>Web site as DB</li></ul>
# </td>
# <td>
# <ul><li>Link structure</li></ul>
# </td>
# <td>
# <ul><li>Interactivity</li></ul>
# </td></tr>
# <tr>
# <th>Main data
# </th>
# <td>
# <ul><li>Text documents</li>
# <li><a href="/wiki/Hypertext" title="Hypertext">Hypertext</a> documents</li></ul>
# </td>
# <td>
# <ul><li>Hypertext documents</li></ul>
# </td>
# <td>
# <ul><li>Link structure</li></ul>
# </td>
# <td>
# <ul><li>Server logs</li>
# <li>Browser logs</li></ul>
# </td></tr>
# <tr>
# <th>Representation
# </th>
# <td>
# <ul><li><a href="/wiki/Bag_of_words" class="mw-redirect" title="Bag of words">Bag of words</a>, <a href="/wiki/N-gram" title="N-gram">n-gram</a> terms</li>
# <li>phrases, concepts or <a href="/wiki/Ontology_(information_science)" title="Ontology (information science)">ontology</a></li>
# <li>Relational</li></ul>
# </td>
# <td>
# <ul><li>Edge labed graph</li>
# <li>Relational</li></ul>
# </td>
# <td>
# <ul><li>Graph</li></ul>
# </td>
# <td>
# <ul><li>Relational table</li>
# <li>Graph</li></ul>
# </td></tr>
# <tr>
# <th>Method
# </th>
# <td>
# <ul><li><a href="/wiki/Machine_learning" title="Machine learning">Machine learning</a></li>
# <li>Statistical (including <a href="/wiki/Natural_language_processing" title="Natural language processing">NLP</a>)</li></ul>
# </td>
# <td>
# <ul><li>Proprietary algorithms</li>
# <li><a href="/wiki/Association_rules" class="mw-redirect" title="Association rules">Association rules</a></li></ul>
# </td>
# <td>
# <ul><li>Proprietary algorithms</li></ul>
# </td>
# <td>
# <ul><li>Machine learning</li>
# <li>Statistical</li>
# <li>Association rules</li></ul>
# </td></tr>
# <tr>
# <th>Application categories
# </th>
# <td>
# <ul><li><a href="/wiki/Categorization" title="Categorization">Categorization</a></li>
# <li><a href="/wiki/Data_clustering" class="mw-redirect" title="Data clustering">Clustering</a></li>
# <li>Finding extract rules</li>
# <li>Finding patterns in text</li></ul>
# </td>
# <td>
# <ul><li>Finding frequent sub structures</li>
# <li>Web site schema discovery</li></ul>
# </td>
# <td>
# <ul><li>Categorization</li>
# <li>Clustering</li></ul>
# </td>
# <td>
# <ul><li>Site construction</li>
# <li>Adaptation and management</li></ul>
# </td></tr></tbody></table>
# <h2><span class="mw-headline" id="Web_usage_mining">Web usage mining</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=2" title="Edit section: Web usage mining">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Web Usage Mining is the application of <a href="/wiki/Data_mining" title="Data mining">data mining</a> techniques to discover interesting <a href="/w/index.php?title=Usage_pattern&amp;action=edit&amp;redlink=1" class="new" title="Usage pattern (page does not exist)">usage patterns</a> from Web data in order to understand and better serve the needs of <a href="/wiki/Web-based_application" class="mw-redirect" title="Web-based application">Web-based applications</a>.
# Usage data captures the identity or origin of Web users along with their <a href="/w/index.php?title=Browsing_behavior&amp;action=edit&amp;redlink=1" class="new" title="Browsing behavior (page does not exist)">browsing behavior</a> at a Web site.
# </p><p>Web usage mining itself can be classified further depending on the kind of usage data considered:
# </p>
# <ul><li><b>Web Server Data</b>: The user logs are collected by the <a href="/wiki/Web_server" title="Web server">Web server</a>. Typical data includes IP address, page reference and access time.</li>
# <li><b>Application Server Data</b>: Commercial application servers have significant features to enable <a href="/wiki/E-commerce" title="E-commerce">e-commerce</a> applications to be built on top of them with little effort. A key feature is the ability to track various kinds of business events and log them in application server logs.</li>
# <li><b>Application Level Data</b>: New kinds of events can be defined in an application, and logging can be turned on for them thus generating histories of these specially defined events. Many end applications require a combination of one or more of the techniques applied in the categories above.</li></ul>
# <p>Studies related to work<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">&#91;2&#93;</a></sup> are concerned with two areas: constraint-based data mining algorithms applied in Web Usage Mining and developed software tools (systems). Costa and Seco demonstrated that web log mining can be used to extract <a href="/wiki/Semantic" class="mw-redirect" title="Semantic">semantic</a> information (<a href="/wiki/Hyponymy" class="mw-redirect" title="Hyponymy">hyponymy</a> relationships in particular) about the user and a given community.
# </p>
# <h3><span class="mw-headline" id="Pros">Pros</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=3" title="Edit section: Pros">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Web usage mining essentially has many advantages which makes this technology attractive to corporations including government agencies. This technology has enabled e-commerce to do <a href="/wiki/Personalized_marketing" title="Personalized marketing">personalized marketing</a>, which eventually results in higher trade volumes. Government agencies are using this technology to classify threats and <a href="/wiki/Fight_against_terrorism" class="mw-redirect" title="Fight against terrorism">fight against terrorism</a>. The predicting capability of mining applications can benefit society by identifying criminal activities. Companies can establish better <a href="/wiki/Customer_relationship" class="mw-redirect" title="Customer relationship">customer relationship</a> by understanding the needs of the customer better and reacting to customer needs faster. Companies can find, attract and retain customers; they can save on production costs by utilizing the acquired insight of customer requirements. They can increase <a href="/wiki/Profitability" class="mw-redirect" title="Profitability">profitability</a> by <a href="/wiki/Target_pricing" class="mw-redirect" title="Target pricing">target pricing</a> based on the <a href="/wiki/User_profiling" class="mw-redirect" title="User profiling">profiles</a> created. They can even find customers who might default to a competitor the company will try to retain the customer by providing promotional offers to the specific customer, thus reducing the risk of losing a customer or customers.
# </p><p>More benefits of web usage mining, particularly in the area of <a href="/wiki/Personalization" title="Personalization">personalization</a>, are outlined in specific frameworks such as the <a href="/wiki/Probabilistic_latent_semantic_analysis" title="Probabilistic latent semantic analysis">Probabilistic Latent Semantic Analysis</a> model, which offer additional features to the <a href="/wiki/User_behavior_analytics" title="User behavior analytics">user behavior</a> and access pattern.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3">&#91;3&#93;</a></sup> This is because the process provides the user with more relevant content through collaborative recommendation. These models also demonstrate a capability in web usage mining technology to address problems associated with traditional techniques such as biases and questions regarding validity since the data and patterns obtained are not subjective and do not degrade over time.<sup id="cite_ref-4" class="reference"><a href="#cite_note-4">&#91;4&#93;</a></sup> There are also elements unique to web usage mining that can show the technology's benefits and these include the way semantic knowledge is applied when interpreting, analyzing, and reasoning about usage patterns during the mining phase.<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">&#91;5&#93;</a></sup>
# </p>
# <h3><span class="mw-headline" id="Cons">Cons</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=4" title="Edit section: Cons">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Web usage mining by itself does not create issues, but this technology when used on <a href="/wiki/Personal_data" title="Personal data">data of personal nature</a> might cause concerns. The most criticized ethical issue involving web usage mining is the invasion of <a href="/wiki/Internet_privacy" title="Internet privacy">privacy</a>. Privacy is considered lost when information concerning an individual is obtained, used, or disseminated, especially if this occurs without their knowledge or consent.<sup id="cite_ref-Lita_van_Wel_and_Lambèr_Royakkers_2004_6-0" class="reference"><a href="#cite_note-Lita_van_Wel_and_Lambèr_Royakkers_2004-6">&#91;6&#93;</a></sup> The obtained data will be analyzed, and <a href="/wiki/Data_clustering" class="mw-redirect" title="Data clustering">clustered</a> to form profiles; the data will be made <a href="/wiki/Anonymization" class="mw-redirect" title="Anonymization">anonymous</a> before clustering so that there are no personal profiles.<sup id="cite_ref-Lita_van_Wel_and_Lambèr_Royakkers_2004_6-1" class="reference"><a href="#cite_note-Lita_van_Wel_and_Lambèr_Royakkers_2004-6">&#91;6&#93;</a></sup> Thus these applications de-<a href="/wiki/Personalization" title="Personalization">individualize</a> the users by judging them by their mouse clicks. De-individualization, can be defined as a tendency of judging and treating people on the basis of group characteristics instead of on their own individual characteristics and merits.<sup id="cite_ref-Lita_van_Wel_and_Lambèr_Royakkers_2004_6-2" class="reference"><a href="#cite_note-Lita_van_Wel_and_Lambèr_Royakkers_2004-6">&#91;6&#93;</a></sup>
# </p><p>Another important concern is that the companies collecting the data for a specific purpose might use the data for totally different purposes, and this essentially violates the user’s interests.
# </p><p>The growing trend of selling personal data as a commodity encourages website owners to trade personal data obtained from their site. This trend has increased the amount of data being captured and traded increasing the likeliness of one’s privacy being invaded. The companies which buy the data are obliged make it anonymous and these companies are considered authors of any specific release of mining patterns. They are legally responsible for the contents of the release; any inaccuracies in the release will result in serious lawsuits, but there is no law preventing them from trading the data.
# </p><p>Some mining algorithms might use controversial attributes like sex, race, religion, or sexual orientation to categorize individuals. These practices might be against the anti-discrimination legislation.<sup id="cite_ref-7" class="reference"><a href="#cite_note-7">&#91;7&#93;</a></sup> The applications make it hard to identify the use of such controversial attributes, and there is no strong rule against the usage of such algorithms with such attributes. This process could result in denial of service or a privilege to an individual based on his race, religion or sexual orientation. Right now this situation can be avoided by the high ethical standards maintained by the data mining company.
# The collected data is being made anonymous so that, the obtained data and the obtained patterns cannot be traced back to an individual. It might look as if this poses no threat to one’s privacy, however additional information can be inferred by the application by combining two separate unscrupulous data from the user.
# </p>
# <h2><span class="mw-headline" id="Web_structure_mining">Web structure mining</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=5" title="Edit section: Web structure mining">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <table class="box-Expand_section plainlinks metadata ambox mbox-small-left ambox-content" role="presentation"><tbody><tr><td class="mbox-image"><a href="/wiki/File:Wiki_letter_w_cropped.svg" class="image"><img alt="[icon]" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/20px-Wiki_letter_w_cropped.svg.png" decoding="async" width="20" height="14" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/30px-Wiki_letter_w_cropped.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1c/Wiki_letter_w_cropped.svg/40px-Wiki_letter_w_cropped.svg.png 2x" data-file-width="44" data-file-height="31" /></a></td><td class="mbox-text"><div class="mbox-text-span">This section <b>needs expansion</b>. <small>You can help by <a class="external text" href="//en.wikipedia.org/w/index.php?title=Web_mining&amp;action=edit&amp;section=">adding to it</a>.</small>  <small class="date-container"><i>(<span class="date">June 2015</span>)</i></small></div></td></tr></tbody></table>
# <p>Web structure mining uses <a href="/wiki/Graph_theory" title="Graph theory">graph theory</a> to analyze the node and connection structure of a web site. According to the type of web structural data, web structure mining can be divided into two kinds:
# </p>
# <ol><li>Extracting patterns from hyperlinks in the web: a <a href="/wiki/Hyperlink" title="Hyperlink">hyperlink</a> is a structural component that connects the web page to a different location.</li>
# <li>Mining the <a href="/wiki/Web_document" class="mw-redirect" title="Web document">document</a> structure: analysis of the tree-like structure of page structures to describe <a href="/wiki/HTML" title="HTML">HTML</a> or <a href="/wiki/XML" title="XML">XML</a> tag usage.</li></ol>
# <p>Web structure mining terminology:
# </p>
# <ul><li>web graph: <a href="/wiki/Directed_graph" title="Directed graph">directed graph</a> representing web.</li>
# <li>node: web page in graph.</li>
# <li>edge: hyperlinks.</li>
# <li>in degree: number of links pointing to particular node.</li>
# <li>out degree: number of links generated  from particular node.</li></ul>
# <p>Techniques of web structure mining:
# </p>
# <ul><li><a href="/wiki/PageRank" title="PageRank">PageRank</a>: this algorithm is used by <a href="/wiki/Google" title="Google">Google</a> to rank search results. The name of this algorithm is given by Google-founder <a href="/wiki/Larry_Page" title="Larry Page">Larry Page</a>. The rank of a page is decided by the number of links pointing to the target node.</li></ul>
# <h2><span class="mw-headline" id="Web_content_mining">Web content mining</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=6" title="Edit section: Web content mining">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Web content mining is the mining, extraction and integration of useful data, information and knowledge from Web page content. The heterogeneity and the <a href="/wiki/Unstructured_data" title="Unstructured data">lack of structure</a> that permits much of the ever-expanding <a href="/wiki/Information_source" title="Information source">information sources</a> on the World Wide Web, such as <a href="/wiki/Hypertext" title="Hypertext">hypertext</a> documents, makes automated discovery, organization, and search and indexing tools of the Internet and the World Wide Web such as <a href="/wiki/Lycos" title="Lycos">Lycos</a>, <a href="/wiki/Alta_Vista" class="mw-redirect" title="Alta Vista">Alta Vista</a>, <a href="/wiki/WebCrawler" title="WebCrawler">WebCrawler</a>, <a href="/wiki/Aliweb" title="Aliweb">Aliweb</a>, <a href="/wiki/MetaCrawler" title="MetaCrawler">MetaCrawler</a>, and others provide some comfort to users, but they do not generally provide structural information nor categorize, filter, or interpret documents. These factors have prompted researchers to develop more intelligent tools for <a href="/wiki/Information_retrieval" title="Information retrieval">information retrieval</a>, such as intelligent <a href="/wiki/Web_agent" class="mw-redirect" title="Web agent">web agents</a>, as well as to extend database and data mining techniques to provide a higher level of organization for <a href="/wiki/Semi-structured_data" title="Semi-structured data">semi-structured data</a> available on the web. The agent-based approach to web mining involves the development of sophisticated <a href="/wiki/Artificial_intelligence" title="Artificial intelligence">AI systems</a> that can act <a href="/wiki/Autonomous_agent" title="Autonomous agent">autonomously</a> or semi-autonomously on behalf of a particular user, to discover and organize web-based information.
# </p><p>Web content mining is differentiated from two different points of view:<sup id="cite_ref-8" class="reference"><a href="#cite_note-8">&#91;8&#93;</a></sup> Information Retrieval View and Database View.<sup id="cite_ref-9" class="reference"><a href="#cite_note-9">&#91;9&#93;</a></sup> summarized the research works done for unstructured data and semi-structured data from information retrieval view. It shows that most of the researches use bag of words, which is based on the statistics about single words in isolation, to represent unstructured text and take single word found in the training corpus as features. For the semi-structured data, all the works utilize the HTML structures inside the documents and some utilized the hyperlink structure between the documents for document representation. As for the database view, in order to have the better <a href="/wiki/Information_management" title="Information management">information management</a> and querying on the web, the mining always tries to infer the structure of the web site to transform a web site to become a database.
# </p><p>There are several ways to represent documents; vector space model is typically used. The documents constitute the whole vector space.  This representation does not realize the importance of words in a document. To resolve this, <a href="/wiki/Tf-idf" class="mw-redirect" title="Tf-idf">tf-idf</a> (Term Frequency Times Inverse Document Frequency) is introduced.
# </p><p>By multi-scanning the document, we can implement feature selection. Under the condition that the category result is rarely affected, the extraction of feature subset is needed. The general algorithm is to construct an evaluating function to evaluate the features. As feature set, <a href="/wiki/Information_gain" class="mw-redirect" title="Information gain">information gain</a>, <a href="/wiki/Cross_entropy" title="Cross entropy">cross entropy</a>, <a href="/wiki/Mutual_information" title="Mutual information">mutual information</a>, and <a href="/wiki/Odds_ratio" title="Odds ratio">odds ratio</a> are usually used.
# The classifier and <a href="/wiki/Pattern_analysis" class="mw-redirect" title="Pattern analysis">pattern analysis</a> methods of text data mining are very similar to traditional data mining techniques. The usual evaluative merits are <a href="/w/index.php?title=Classification_accuracy&amp;action=edit&amp;redlink=1" class="new" title="Classification accuracy (page does not exist)">classification accuracy</a>, <a href="/wiki/Precision_and_recall" title="Precision and recall">precision and recall</a> and <a href="/w/index.php?title=Information_score&amp;action=edit&amp;redlink=1" class="new" title="Information score (page does not exist)">information score</a>.
# </p><p>Web mining is an important component of content pipeline for <a href="/wiki/Web_portal" title="Web portal">web portals</a>. It is used in data confirmation and validity verification, data integrity and building <a href="/wiki/Taxonomy_for_search_engines" title="Taxonomy for search engines">taxonomies</a>, <a href="/wiki/Content_management" title="Content management">content management</a>, content generation and <a href="/wiki/Opinion_mining" class="mw-redirect" title="Opinion mining">opinion mining</a>.<sup id="cite_ref-10" class="reference"><a href="#cite_note-10">&#91;10&#93;</a></sup>
# </p>
# <h3><span class="mw-headline" id="Web_content_mining_in_foreign_languages">Web content mining in foreign languages</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=7" title="Edit section: Web content mining in foreign languages">edit</a><span class="mw-editsection-bracket">]</span></span></h3>
# <h4><span class="mw-headline" id="Chinese">Chinese</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=8" title="Edit section: Chinese">edit</a><span class="mw-editsection-bracket">]</span></span></h4>
# <p>The <a href="/wiki/Language_code" title="Language code">language code</a> of <a href="/wiki/Chinese_writing" class="mw-redirect" title="Chinese writing">Chinese</a> words is very complicated compared to that of English. The <a href="/wiki/GB_18030" title="GB 18030">GB</a>, <a href="/wiki/Big5" title="Big5">Big5</a> and <a href="/wiki/HZ_(character_encoding)" title="HZ (character encoding)">HZ code</a> are common Chinese word codes in web documents. Before text mining, one needs to identify the code standard of the HTML documents and transform it into inner code, then use other data mining techniques to find useful knowledge and useful patterns.
# </p>
# <h2><span class="mw-headline" id="See_also">See also</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=9" title="Edit section: See also">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><a href="/wiki/Web_intelligence" title="Web intelligence">Web intelligence</a></li>
# <li><a href="/wiki/Web_analytics" title="Web analytics">Web analytics</a></li>
# <li><a href="/wiki/Web_scraping" title="Web scraping">Web scraping</a></li>
# <li><a href="/wiki/Wikipedia:Data_mining_Wikipedia" title="Wikipedia:Data mining Wikipedia">Wikipedia:Data mining Wikipedia</a></li></ul>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Web_mining&amp;action=edit&amp;section=10" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist" style="list-style-type: decimal;">
# <div class="mw-references-wrap"><ol class="references">
# <li id="cite_note-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-1">^</a></b></span> <span class="reference-text"><span class="citation">Galitsky B, Dobrocsi G, de la Rosa JL, Kuznetsov SO.&#32;&#32;<a rel="nofollow" class="external text" href="http://www.hse.ru/data/2013/03/12/1292267437/2011%20Using%20Generalization%20of%20Syntactic%20P..for%20Taxonomy%20Capture%20on%20the%20Web.pdhttps://en.wikipedia.org/w/index.php?title=Web_mining&amp;action=submit#f">Using generalization of syntactic parse trees for taxonomy capture on the web</a>.&#32;<i>ICCS</i>.&#32;2011;8323.</span></span>
# </li>
# <li id="cite_note-2"><span class="mw-cite-backlink"><b><a href="#cite_ref-2">^</a></b></span> <span class="reference-text">Weichbroth et al.</span>
# </li>
# <li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text"><cite class="citation book">Ngu, Anne; Kitsuregawa, Masaru; Chung, Jen-Yao; Neuhold, Erich; Sheng, Quan (2005). <i>Web Information Systems Engineering - WISE 2005</i>. Berlin: Springer. p.&#160;15. <a href="/wiki/International_Standard_Book_Number" title="International Standard Book Number">ISBN</a>&#160;<a href="/wiki/Special:BookSources/9783540300175" title="Special:BookSources/9783540300175"><bdi>9783540300175</bdi></a>.</cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=book&amp;rft.btitle=Web+Information+Systems+Engineering+-+WISE+2005&amp;rft.place=Berlin&amp;rft.pages=15&amp;rft.pub=Springer&amp;rft.date=2005&amp;rft.isbn=9783540300175&amp;rft.aulast=Ngu&amp;rft.aufirst=Anne&amp;rft.au=Kitsuregawa%2C+Masaru&amp;rft.au=Chung%2C+Jen-Yao&amp;rft.au=Neuhold%2C+Erich&amp;rft.au=Sheng%2C+Quan&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AWeb+mining" class="Z3988"></span><style data-mw-deduplicate="TemplateStyles:r886058088">.mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation .cs1-lock-free a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-subscription a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:inherit;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}</style></span>
# </li>
# <li id="cite_note-4"><span class="mw-cite-backlink"><b><a href="#cite_ref-4">^</a></b></span> <span class="reference-text"><cite class="citation book">Bauknecht, Kurt; Madria, Sanjay; Pernul, Gunther (2000). <i>Electronic Commerce and Web Technologies: First International Conference, EC-Web 2000 London, UK, September 4-6, 2000 Proceedings</i>. Berlin: Springer. p.&#160;165. <a href="/wiki/International_Standard_Book_Number" title="International Standard Book Number">ISBN</a>&#160;<a href="/wiki/Special:BookSources/978-3540679813" title="Special:BookSources/978-3540679813"><bdi>978-3540679813</bdi></a>.</cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=book&amp;rft.btitle=Electronic+Commerce+and+Web+Technologies%3A+First+International+Conference%2C+EC-Web+2000+London%2C+UK%2C+September+4-6%2C+2000+Proceedings&amp;rft.place=Berlin&amp;rft.pages=165&amp;rft.pub=Springer&amp;rft.date=2000&amp;rft.isbn=978-3540679813&amp;rft.aulast=Bauknecht&amp;rft.aufirst=Kurt&amp;rft.au=Madria%2C+Sanjay&amp;rft.au=Pernul%2C+Gunther&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AWeb+mining" class="Z3988"></span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r886058088"/></span>
# </li>
# <li id="cite_note-5"><span class="mw-cite-backlink"><b><a href="#cite_ref-5">^</a></b></span> <span class="reference-text"><cite class="citation book">Scime, Anthony (2005). <i>Web Mining: Applications and Techniques</i>. Hershey, PA: Idea Group Publishing. p.&#160;282. <a href="/wiki/International_Standard_Book_Number" title="International Standard Book Number">ISBN</a>&#160;<a href="/wiki/Special:BookSources/978-1591404149" title="Special:BookSources/978-1591404149"><bdi>978-1591404149</bdi></a>.</cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=book&amp;rft.btitle=Web+Mining%3A+Applications+and+Techniques&amp;rft.place=Hershey%2C+PA&amp;rft.pages=282&amp;rft.pub=Idea+Group+Publishing&amp;rft.date=2005&amp;rft.isbn=978-1591404149&amp;rft.aulast=Scime&amp;rft.aufirst=Anthony&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AWeb+mining" class="Z3988"></span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r886058088"/></span>
# </li>
# <li id="cite_note-Lita_van_Wel_and_Lambèr_Royakkers_2004-6"><span class="mw-cite-backlink">^ <a href="#cite_ref-Lita_van_Wel_and_Lambèr_Royakkers_2004_6-0"><sup><i><b>a</b></i></sup></a> <a href="#cite_ref-Lita_van_Wel_and_Lambèr_Royakkers_2004_6-1"><sup><i><b>b</b></i></sup></a> <a href="#cite_ref-Lita_van_Wel_and_Lambèr_Royakkers_2004_6-2"><sup><i><b>c</b></i></sup></a></span> <span class="reference-text"><cite class="citation journal">Lita van Wel &amp; Lambèr Royakkers (2004). <a rel="nofollow" class="external text" href="http://alexandria.tue.nl/repository/freearticles/612259.pdf">"Ethical issues in web data mining"</a> <span class="cs1-format">(PDF)</span>. <i>Ethical Issues in Web Data Mining</i>.</cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Ethical+Issues+in+Web+Data+Mining&amp;rft.atitle=Ethical+issues+in+web+data+mining&amp;rft.date=2004&amp;rft.au=Lita+van+Wel&amp;rft.au=Lamb%C3%A8r+Royakkers&amp;rft_id=http%3A%2F%2Falexandria.tue.nl%2Frepository%2Ffreearticles%2F612259.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AWeb+mining" class="Z3988"></span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r886058088"/>.</span>
# </li>
# <li id="cite_note-7"><span class="mw-cite-backlink"><b><a href="#cite_ref-7">^</a></b></span> <span class="reference-text"><cite class="citation journal">Kirsten Wahlstrom; John F. Roddick; Vladimir Estivill-Castro; Denise de Vries (2007). <a rel="nofollow" class="external text" href="http://www.cis.unisa.edu.au/~ciskw/WahlstromRoddickSarreEstivillCastro&amp;DeVries2007.pdf">"Legal and Technical Issues of Privacy Preservation in Data Mining"</a> <span class="cs1-format">(PDF)</span>. <i>Legal and Technical Issues of Privacy Preservation in Data Mining</i>.</cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=Legal+and+Technical+Issues+of+Privacy+Preservation+in+Data+Mining&amp;rft.atitle=Legal+and+Technical+Issues+of+Privacy+Preservation+in+Data+Mining&amp;rft.date=2007&amp;rft.au=Kirsten+Wahlstrom&amp;rft.au=John+F.+Roddick&amp;rft.au=Vladimir+Estivill-Castro&amp;rft.au=Denise+de+Vries&amp;rft_id=http%3A%2F%2Fwww.cis.unisa.edu.au%2F~ciskw%2FWahlstromRoddickSarreEstivillCastro%26DeVries2007.pdf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AWeb+mining" class="Z3988"></span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r886058088"/>.</span>
# </li>
# <li id="cite_note-8"><span class="mw-cite-backlink"><b><a href="#cite_ref-8">^</a></b></span> <span class="reference-text"><cite class="citation web">Wang, Yan. <a rel="nofollow" class="external text" href="https://docs.google.com/open?id=1nU1vrz-gBtSJk3bkb1ls_QuGX2nUPPemECPFlCx0C75MvmQdSqPci6LZWJYf">"Web Mining and Knowledge Discovery of Usage Patterns"</a>.</cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Web+Mining+and+Knowledge+Discovery+of+Usage+Patterns&amp;rft.aulast=Wang&amp;rft.aufirst=Yan&amp;rft_id=https%3A%2F%2Fdocs.google.com%2Fopen%3Fid%3D1nU1vrz-gBtSJk3bkb1ls_QuGX2nUPPemECPFlCx0C75MvmQdSqPci6LZWJYf&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AWeb+mining" class="Z3988"></span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r886058088"/></span>
# </li>
# <li id="cite_note-9"><span class="mw-cite-backlink"><b><a href="#cite_ref-9">^</a></b></span> <span class="reference-text"><cite class="citation journal">Kosala, Raymond; Hendrik Blockeel (July 2000). "Web Mining Research: A Survey". <i>SIGKDD Explorations</i>. <b>2</b> (1). <a href="/wiki/ArXiv" title="ArXiv">arXiv</a>:<span class="cs1-lock-free" title="Freely accessible"><a rel="nofollow" class="external text" href="//arxiv.org/abs/cs.LG/0011033">cs.LG/0011033</a></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=article&amp;rft.jtitle=SIGKDD+Explorations&amp;rft.atitle=Web+Mining+Research%3A+A+Survey&amp;rft.volume=2&amp;rft.issue=1&amp;rft.date=2000-07&amp;rft_id=info%3Aarxiv%2Fcs.LG%2F0011033&amp;rft.aulast=Kosala&amp;rft.aufirst=Raymond&amp;rft.au=Hendrik+Blockeel&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AWeb+mining" class="Z3988"></span><link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r886058088"/></span>
# </li>
# ...
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 							<li id="ca-nstab-main" class="selected"><span><a href="/wiki/Web_mining" title="View the content page [c]" accesskey="c">Article</a></span></li><li id="ca-talk"><span><a href="/wiki/Talk:Web_mining" rel="discussion" title="Discussion about the content page [t]" accesskey="t">Talk</a></span></li>						</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<input type="checkbox" class="vectorMenuCheckbox" aria-labelledby="p-variants-label" />
# 						<h3 id="p-variants-label">
# 							<span>Variants</span>
# 						</h3>
# 						<ul class="menu">
# 													</ul>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 							<li id="ca-view" class="collapsible selected"><span><a href="/wiki/Web_mining">Read</a></span></li><li id="ca-edit" class="collapsible"><span><a href="/w/index.php?title=Web_mining&amp;action=edit" title="Edit this page [e]" accesskey="e">Edit</a></span></li><li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Web_mining&amp;action=history" title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>						</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<input type="checkbox" class="vectorMenuCheckbox" aria-labelledby="p-cactions-label" />
# 						<h3 id="p-cactions-label"><span>More</span></h3>
# 						<ul class="menu">
# 													</ul>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 								<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id="p-navigation" aria-labelledby="p-navigation-label">
# 			<h3 id="p-navigation-label">Navigation</h3>
# 			<div class="body">
# 								<ul>
# 					<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>				</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id="p-interaction" aria-labelledby="p-interaction-label">
# 			<h3 id="p-interaction-label">Interaction</h3>
# 			<div class="body">
# 								<ul>
# 					<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>				</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id="p-tb" aria-labelledby="p-tb-label">
# 			<h3 id="p-tb-label">Tools</h3>
# 			<div class="body">
# 								<ul>
# 					<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Web_mining" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Web_mining" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Web_mining&amp;oldid=904363144" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Web_mining&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q785337" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Web_mining&amp;id=904363144" title="Information on how to cite this page">Cite this page</a></li>				</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id="p-coll-print_export" aria-labelledby="p-coll-print_export-label">
# 			<h3 id="p-coll-print_export-label">Print/export</h3>
# 			<div class="body">
# 								<ul>
# 					<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Web+mining">Create a book</a></li><li id="coll-download-as-rl"><a href="/w/index.php?title=Special:ElectronPdf&amp;page=Web+mining&amp;action=show-download-screen">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Web_mining&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>				</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id="p-lang" aria-labelledby="p-lang-label">
# 			<h3 id="p-lang-label">Languages</h3>
# 			<div class="body">
# 								<ul>
# 					<li class="interlanguage-link interwiki-ar"><a href="https://ar.wikipedia.org/wiki/%D8%AA%D9%86%D9%82%D9%8A%D8%A8_%D8%A7%D9%84%D9%88%D9%8A%D8%A8" title="تنقيب الويب – Arabic" lang="ar" hreflang="ar" class="interlanguage-link-target">العربية</a></li><li class="interlanguage-link interwiki-de"><a href="https://de.wikipedia.org/wiki/Web_Mining" title="Web Mining – German" lang="de" hreflang="de" class="interlanguage-link-target">Deutsch</a></li><li class="interlanguage-link interwiki-es"><a href="https://es.wikipedia.org/wiki/Web_mining" title="Web mining – Spanish" lang="es" hreflang="es" class="interlanguage-link-target">Español</a></li><li class="interlanguage-link interwiki-eu"><a href="https://eu.wikipedia.org/wiki/Web-meatzaritza" title="Web-meatzaritza – Basque" lang="eu" hreflang="eu" class="interlanguage-link-target">Euskara</a></li><li class="interlanguage-link interwiki-fa"><a href="https://fa.wikipedia.org/wiki/%D9%85%D8%B9%D8%AF%D9%86_%D9%88%D8%A8" title="معدن وب – Persian" lang="fa" hreflang="fa" class="interlanguage-link-target">فارسی</a></li><li class="interlanguage-link interwiki-fr"><a href="https://fr.wikipedia.org/wiki/Fouille_du_web" title="Fouille du web – French" lang="fr" hreflang="fr" class="interlanguage-link-target">Français</a></li><li class="interlanguage-link interwiki-ko"><a href="https://ko.wikipedia.org/wiki/%EC%9B%B9_%EB%A7%88%EC%9D%B4%EB%8B%9D" title="웹 마이닝 – Korean" lang="ko" hreflang="ko" class="interlanguage-link-target">한국어</a></li><li class="interlanguage-link interwiki-hi"><a href="https://hi.wikipedia.org/wiki/%E0%A4%85%E0%A4%82%E0%A4%A4%E0%A4%B0%E0%A4%9C%E0%A4%BE%E0%A4%B2_%E0%A4%96%E0%A4%A8%E0%A4%A8" title="अंतरजाल खनन – Hindi" lang="hi" hreflang="hi" class="interlanguage-link-target">हिन्दी</a></li><li class="interlanguage-link interwiki-hr"><a href="https://hr.wikipedia.org/wiki/Dubinsko_pretra%C5%BEivanje_interneta" title="Dubinsko pretraživanje interneta – Croatian" lang="hr" hreflang="hr" class="interlanguage-link-target">Hrvatski</a></li><li class="interlanguage-link interwiki-hu"><a href="https://hu.wikipedia.org/wiki/Webb%C3%A1ny%C3%A1szat" title="Webbányászat – Hungarian" lang="hu" hreflang="hu" class="interlanguage-link-target">Magyar</a></li><li class="interlanguage-link interwiki-ja"><a href="https://ja.wikipedia.org/wiki/%E3%82%A6%E3%82%A7%E3%83%96%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0" title="ウェブマイニング – Japanese" lang="ja" hreflang="ja" class="interlanguage-link-target">日本語</a></li><li class="interlanguage-link interwiki-pt"><a href="https://pt.wikipedia.org/wiki/Minera%C3%A7%C3%A3o_da_web" title="Mineração da web – Portuguese" lang="pt" hreflang="pt" class="interlanguage-link-target">Português</a></li><li class="interlanguage-link interwiki-ru"><a href="https://ru.wikipedia.org/wiki/Web_mining" title="Web mining – Russian" lang="ru" hreflang="ru" class="interlanguage-link-target">Русский</a></li><li class="interlanguage-link interwiki-sk"><a href="https://sk.wikipedia.org/wiki/Web_mining" title="Web mining – Slovak" lang="sk" hreflang="sk" class="interlanguage-link-target">Slovenčina</a></li><li class="interlanguage-link interwiki-th"><a href="https://th.wikipedia.org/wiki/%E0%B8%81%E0%B8%B2%E0%B8%A3%E0%B8%97%E0%B8%B3%E0%B9%80%E0%B8%AB%E0%B8%A1%E0%B8%B7%E0%B8%AD%E0%B8%87%E0%B9%80%E0%B8%A7%E0%B9%87%E0%B8%9A" title="การทำเหมืองเว็บ – Thai" lang="th" hreflang="th" class="interlanguage-link-target">ไทย</a></li>				</ul>
# 				<div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Special:EntityPage/Q785337#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 				<div id="footer" role="contentinfo">
# 						<ul id="footer-info">
# 								<li id="footer-info-lastmod"> This page was last edited on 1 July 2019, at 17:30<span class="anonymous-show">&#160;(UTC)</span>.</li>
# 								<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 							</ul>
# 						<ul id="footer-places">
# 								<li id="footer-places-privacy"><a href="https://foundation.wikimedia.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 								<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 								<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 								<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 								<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 								<li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# 								<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Web_mining&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 							</ul>
# 										<ul id="footer-icons" class="noprint">
# 										<li id="footer-copyrightico">
# 						<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>					</li>
# 										<li id="footer-poweredbyico">
# 						<a href="https://www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>					</li>
# 									</ul>
# 						<div style="clear: both;"></div>
# 		</div>
#
#
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.284","walltime":"0.395","ppvisitednodes":{"value":1321,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":29945,"limit":2097152},"templateargumentsize":{"value":3505,"limit":2097152},"expansiondepth":{"value":16,"limit":40},"expensivefunctioncount":{"value":7,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":23187,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  341.670      1 -total"," 53.17%  181.664      1 Template:Reflist"," 32.26%  110.233      1 Template:Cleanup"," 24.21%   82.732      3 Template:Cite_book"," 18.41%   62.902      3 Template:Ambox"," 16.84%   57.536      3 Template:Cite_journal"," 16.12%   55.074      3 Template:Main_other","  9.16%   31.300      1 Template:Category_handler","  5.45%   18.608      1 Template:DMC","  4.82%   16.457      1 Template:More_footnotes"]},"scribunto":{"limitreport-timeusage":{"value":"0.130","limit":"10.000"},"limitreport-memusage":{"value":3874965,"limit":52428800}},"cachereport":{"origin":"mw1332","timestamp":"20190729184924","ttl":2592000,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Web mining","url":"https:\/\/en.wikipedia.org\/wiki\/Web_mining","sameAs":"http:\/\/www.wikidata.org\/entity\/Q785337","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q785337","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-07-08T21:37:06Z","dateModified":"2019-07-01T17:30:12Z"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":116,"wgHostname":"mw1267"});});</script>
# </body>
# </html>

# %%
#the html tags from the content
from bs4 import BeautifulSoup
html = page.text
soup = BeautifulSoup(html,'html.parser')
html_tag = [tag.name for tag in soup.find_all()]
print(html_tag)#all list used in order
print(set(html_tag))#set of list used (no repetition of tag)
# Out:
# ['html', 'head', 'meta', 'title', 'script', 'script', 'link', 'script', 'meta', 'link', 'link', 'meta', 'meta', 'meta', 'meta', 'link', 'link', 'link', 'link', 'link', 'link', 'link', 'link', 'link', 'link', 'link', 'body', 'div', 'div', 'div', 'a', 'div', 'div', 'h1', 'div', 'div', 'div', 'div', 'a', 'a', 'div', 'div', 'table', 'tbody', 'tr', 'td', 'div', 'img', 'td', 'div', 'b', 'a', 'a', 'span', 'a', 'a', 'small', 'i', 'span', 'small', 'i', 'a', 'p', 'b', 'a', 'a', 'p', 'p', 'div', 'input', 'div', 'h2', 'span', 'label', 'ul', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'ul', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'ul', 'li', 'a', 'span', 'span', 'ul', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'ul', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'li', 'a', 'span', 'span', 'h2', 'span', 'span', 'span', 'a', 'span', 'p', 'b', 'b', 'b', 'div', 'div', 'a', 'img', 'div', 'div', 'a', 'table', 'caption', 'span', 'sup', 'a', 'tbody', 'tr', 'th', 'th', 'th', 'th', 'tr', 'th', 'th', 'th', 'tr', 'th', 'td', 'ul', 'li', 'li', 'td', 'ul', 'li', 'li', 'td', 'ul', 'li', 'td', 'ul', 'li', 'tr', 'th', 'td', 'ul', 'li', 'li', 'a', 'td', 'ul', 'li', 'td', 'ul', 'li', 'td', 'ul', 'li', 'li', 'tr', 'th', 'td', 'ul', 'li', 'a', 'a', 'li', 'a', 'li', 'td', 'ul', 'li', 'li', 'td', 'ul', 'li', 'td', 'ul', 'li', 'li', 'tr', 'th', 'td', 'ul', 'li', 'a', 'li', 'a', 'td', 'ul', 'li', 'li', 'a', 'td', 'ul', 'li', 'td', 'ul', 'li', 'li', 'li', 'tr', 'th', 'td', 'ul', 'li', 'a', 'li', 'a', 'li', 'li', 'td', 'ul', 'li', 'li', 'td', 'ul', 'li', 'li', 'td', 'ul', 'li', 'li', 'h2', 'span', 'span', 'span', 'a', 'span', 'p', 'a', 'a', 'a', 'a', 'p', 'ul', 'li', 'b', 'a', 'li', 'b', 'a', 'li', 'b', 'p', 'sup', 'a', 'a', 'a', 'h3', 'span', 'span', 'span', 'a', 'span', 'p', 'a', 'a', 'a', 'a', 'a', 'a', 'p', 'a', 'a', 'a', 'sup', 'a', 'sup', 'a', 'sup', 'a', 'h3', 'span', 'span', 'span', 'a', 'span', 'p', 'a', 'a', 'sup', 'a', 'a', 'a', 'sup', 'a', 'a', 'sup', 'a', 'p', 'p', 'p', 'sup', 'a', 'h2', 'span', 'span', 'span', 'a', 'span', 'table', 'tbody', 'tr', 'td', 'a', 'img', 'td', 'div', 'b', 'small', 'a', 'small', 'i', 'span', 'p', 'a', 'ol', 'li', 'a', 'li', 'a', 'a', 'a', 'p', 'ul', 'li', 'a', 'li', 'li', 'li', 'li', 'p', 'ul', 'li', 'a', 'a', 'a', 'h2', 'span', 'span', 'span', 'a', 'span', 'p', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'p', 'sup', 'a', 'sup', 'a', 'a', 'p', 'a', 'p', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'a', 'p', 'a', 'a', 'a', 'a', 'sup', 'a', 'h3', 'span', 'span', 'span', 'a', 'span', 'h4', 'span', 'span', 'span', 'a', 'span', 'p', 'a', 'a', 'a', 'a', 'a', 'h2', 'span', 'span', 'span', 'a', 'span', 'ul', 'li', 'a', 'li', 'a', 'li', 'a', 'li', 'a', 'h2', 'span', 'span', 'span', 'a', 'span', 'div', 'div', 'ol', 'li', 'span', 'b', 'a', 'span', 'span', 'a', 'i', 'li', 'span', 'b', 'a', 'span', 'li', 'span', 'b', 'a', 'span', 'cite', 'i', 'a', 'a', 'bdi', 'span', 'style', 'li', 'span', 'b', 'a', 'span', 'cite', 'i', 'a', 'a', 'bdi', 'span', 'link', 'li', 'span', 'b', 'a', 'span', 'cite', 'i', 'a', 'a', 'bdi', 'span', 'link', 'li', 'span', 'a', 'sup', 'i', 'b', 'a', 'sup', 'i', 'b', 'a', 'sup', 'i', 'b', 'span', 'cite', 'a', 'span', 'i', 'span', 'link', 'li', 'span', 'b', 'a', 'span', 'cite', 'a', 'span', 'i', 'span', 'link', 'li', 'span', 'b', 'a', 'span', 'cite', 'a', 'span', 'link', 'li', 'span', 'b', 'a', 'span', 'cite', 'i', 'b', 'a', 'span', 'a', 'span', 'link', 'li', 'span', 'b', 'a', 'span', 'span', 'a', 'i', 'h2', 'span', 'span', 'span', 'a', 'span', 'table', 'tbody', 'tr', 'td', 'div', 'img', 'td', 'div', 'a', 'b', 'b', 'a', 'span', 'a', 'a', 'small', 'i', 'span', 'small', 'i', 'a', 'h3', 'span', 'span', 'span', 'a', 'span', 'ul', 'li', 'a', 'h3', 'span', 'span', 'span', 'a', 'span', 'ul', 'li', 'a', 'li', 'li', 'li', 'a', 'li', 'li', 'li', 'a', 'h3', 'span', 'span', ' ...
# {'noscript', 'caption', 'ul', 'li', 'body', 'th', 'cite', 'style', 'head', 'td', 'ol', 'h4', 'small', 'a', 'h2', 'h3', 'form', 'meta', 'span', 'div', 'title', 'i', 'sup', 'p', 'b', 'label', 'html', 'h1', 'img', 'table', 'bdi', 'script', 'input', 'tr', 'tbody', 'link'}

# %%
#filtering the html tags from the content
#removing or extracting useless data
filter_residue = [s.extract() for s in soup(['style', 'script', '[document]', 'head', 'title'])]
#printing useful text
text = soup.get_text()
print(text)
# Out:
# Web mining
#
# From Wikipedia, the free encyclopedia
#
#
# Jump to navigation
# Jump to search
# This article may require cleanup to meet Wikipedia's quality standards. No cleanup reason has been specified. Please help improve this article if you can. (June 2009) (Learn how and when to remove this template message)
# Web mining is the application of data mining techniques to discover patterns from the World Wide Web. As the name proposes, this is information gathered by mining the web. It makes utilization of automated apparatuses to reveal and extricate data from servers and web2 reports, and it permits organizations to get to both organized and unstructured information from browser activities, server logs, website and link structure, page content and different sources.
# The goal of Web structure mining is to generate structural summary about the Web site and Web page. Technically, Web content mining mainly focuses on the structure of inner-document, while Web structure mining tries to discover the link structure of the hyperlinks at the inter-document level. Based on the topology of the hyperlinks, Web structure mining will categorize the Web pages and generate the information, such as the similarity and relationship between different Web sites.
# Web structure mining can also have another direction -- discovering the structure of Web document itself. This type of structure mining can be used to reveal the structure (schema) of Web pages, this would be good for navigation purpose and make it possible to compare/integrate Web page schemes. This type of structure mining will facilitate introducing database techniques for accessing information in Web pages by providing a reference schema.
#
# Contents
#
# 1 Web mining types
# 2 Web usage mining
#
# 2.1 Pros
# 2.2 Cons
#
#
# 3 Web structure mining
# 4 Web content mining
#
# 4.1 Web content mining in foreign languages
#
# 4.1.1 Chinese
#
#
#
#
# 5 See also
# 6 References
# 7 Resources
#
# 7.1 External links
# 7.2 Books
# 7.3 Bibliographic references
#
#
#
#
# Web mining types[edit]
# Web mining can be divided into three different types – Web usage mining, Web content mining and Web structure mining.
#
#  The general relationship between the categories of Web Mining and objectives of Data Mining
#
# Comparison of web mining types[1]
#
#
#
#
# Web content Mining
#
# Web structure mining
#
# Web usage mining
#
#
#
#
# IR view
#
# DB view
#
#
# View of data
#
#
# Unstructured
# Structured
#
#
# Semi-structured
# Web site as DB
#
#
# Link structure
#
#
# Interactivity
#
#
# Main data
#
#
# Text documents
# Hypertext documents
#
#
# Hypertext documents
#
#
# Link structure
#
#
# Server logs
# Browser logs
#
#
# Representation
#
#
# Bag of words, n-gram terms
# phrases, concepts or ontology
# Relational
#
#
# Edge labed graph
# Relational
#
#
# Graph
#
#
# Relational table
# Graph
#
#
# Method
#
#
# Machine learning
# Statistical (including NLP)
#
#
# Proprietary algorithms
# Association rules
#
#
# Proprietary algorithms
#
#
# Machine learning
# Statistical
# Association rules
#
#
# Application categories
#
#
# Categorization
# Clustering
# Finding extract rules
# Finding patterns in text
#
#
# Finding frequent sub structures
# Web site schema discovery
#
#
# Categorization
# Clustering
#
#
# Site construction
# Adaptation and management
#
# Web usage mining[edit]
# Web Usage Mining is the application of data mining techniques to discover interesting usage patterns from Web data in order to understand and better serve the needs of Web-based applications.
# Usage data captures the identity or origin of Web users along with their browsing behavior at a Web site.
# Web usage mining itself can be classified further depending on the kind of usage data considered:
#
# Web Server Data: The user logs are collected by the Web server. Typical data includes IP address, page reference and access time.
# Application Server Data: Commercial application servers have significant features to enable e-commerce applications to be built on top of them with little effort. A key feature is the ability to track various kinds of business events and log them in application server logs.
# Application Level Data: New kinds of events can be defined in an application, and logging can be turned on for them thus generating histories of these specially defined events. Many end applications require a combination of one or more of the techniques applied in the categories above.
# Studies related to work[2] are concerned with two areas: constraint-based data mining algorithms applied in Web Usage Mining and developed software tools (systems). Costa and Seco demonstrated that web log mining can be used to extract semantic information (hyponymy relationships in particular) about the user and a given community.
#
# Pros[edit]
# Web usage mining essentially has many advantages which makes this technology attractive to corporations including government agencies. This technology has enabled e-commerce to do personalized marketing, which eventually results in higher trade volumes. Government agencies are using this technology to classify threats and fight against terrorism. The predicting capability of mining applications can benefit society by identifying criminal activities. Companies can establish better customer relationship by understanding the needs of the customer better and reacting to customer needs faster. Companies can find, attract and retain customers; they can save on production costs by utilizing the acquired insight of customer requirements. They can increase profitability by target pricing based on the profiles created. They can even find customers who might default to a competitor the company will try to retain the customer by providing promotional offers to the specific customer, thus reducing the risk of losing a customer or customers.
# More benefits of web usage mining, particularly in the area of personalization, are outlined in specific frameworks such as the Probabilistic Latent Semantic Analysis model, which offer additional features to the user behavior and access pattern.[3] This is because the process provides the user with more relevant content through collaborative recommendation. These models also demonstrate a capability in web usage mining technology to address problems associated with traditional techniques such as biases and questions regarding validity since the data and patterns obtained are not subjective and do not degrade over time.[4] There are also elements unique to web usage mining that can show the technology's benefits and these include the way semantic knowledge is applied when interpreting, analyzing, and reasoning about usage patterns during the mining phase.[5]
#
# Cons[edit]
# Web usage mining by itself does not create issues, but this technology when used on data of personal nature might cause concerns. The most criticized ethical issue involving web usage mining is the invasion of privacy. Privacy is considered lost when information concerning an individual is obtained, used, or disseminated, especially if this occurs without their knowledge or consent.[6] The obtained data will be analyzed, and clustered to form profiles; the data will be made anonymous before clustering so that there are no personal profiles.[6] Thus these applications de-individualize the users by judging them by their mouse clicks. De-individualization, can be defined as a tendency of judging and treating people on the basis of group characteristics instead of on their own individual characteristics and merits.[6]
# Another important concern is that the companies collecting the data for a specific purpose might use the data for totally different purposes, and this essentially violates the user’s interests.
# The growing trend of selling personal data as a commodity encourages website owners to trade personal data obtained from their site. This trend has increased the amount of data being captured and traded increasing the likeliness of one’s privacy being invaded. The companies which buy the data are obliged make it anonymous and these companies are considered authors of any specific release of mining patterns. They are legally responsible for the contents of the release; any inaccuracies in the release will result in serious lawsuits, but there is no law preventing them from trading the data.
# Some mining algorithms might use controversial attributes like sex, race, religion, or sexual orientation to categorize individuals. These practices might be against the anti-discrimination legislation.[7] The applications make it hard to identify the use of such controversial attributes, and there is no strong rule against the usage of such algorithms with such attributes. This process could result in denial of service or a privilege to an individual based on his race, religion or sexual orientation. Right now this situation can be avoided by the high ethical standards maintained by the data mining company.
# The collected data is being made anonymous so that, the obtained data and the obtained patterns cannot be traced back to an individual. It might look as if this poses no threat to one’s privacy, however additional information can be inferred by the application by combining two separate unscrupulous data from the user.
#
# Web structure mining[edit]
# This section needs expansion. You can help by adding to it. (June 2015)
# Web structure mining uses graph theory to analyze the node and connection structure of a web site. According to the type of web structural data, web structure mining can be divided into two kinds:
#
# Extracting patterns from hyperlinks in the web: a hyperlink is a structural component that connects the web page to a different location.
# Mining the document structure: analysis of the tree-like structure of page structures to describe HTML or XML tag usage.
# Web structure mining terminology:
#
# web graph: directed graph representing web.
# node: web page in graph.
# edge: hyperlinks.
# in degree: number of links pointing to particular node.
# out degree: number of links generated  from particular node.
# Techniques of web structure mining:
#
# PageRank: this algorithm is used by Google to rank search results. The name of this algorithm is given by Google-founder Larry Page. The rank of a page is decided by the number of links pointing to the target node.
# Web content mining[edit]
# Web content mining is the mining, extraction and integration of useful data, information and knowledge from Web page content. The heterogeneity and the lack of structure that permits much of the ever-expanding information sources on the World Wide Web, such as hypertext documents, makes automated discovery, organization, and search and indexing tools of the Internet and the World Wide Web such as Lycos, Alta Vista, WebCrawler, Aliweb, MetaCrawler, and others provide some comfort to users, but they do not generally provide structural information nor categorize, filter, or interpret documents. These factors have prompted researchers to develop more intelligent tools for information retrieval, such as intelligent web agents, as well as to extend database and data mining techniques to provide a higher level of organization for semi-structured data available on the web. The agent-based approach to web mining involves the development of sophisticated AI systems that can act autonomously or semi-autonomously on behalf of a particular user, to discover and organize web-based information.
# Web content mining is differentiated from two different points of view:[8] Information Retrieval View and Database View.[9] summarized the research works done for unstructured data and semi-structured data from information retrieval view. It shows that most of the researches use bag of words, which is based on the statistics about single words in isolation, to represent unstructured text and take single word found in the training corpus as features. For the semi-structured data, all the works utilize the HTML structures inside the documents and some utilized the hyperlink structure between the documents for document representation. As for the database view, in order to have the better information management and querying on the web, the mining always tries to infer the structure of the web site to transform a web site to become a database.
# There are several ways to represent documents; vector space model is typically used. The documents constitute the whole vector space.  This representation does not realize the importance of words in a document. To resolve this, tf-idf (Term Frequency Times Inverse Document Frequency) is introduced.
# By multi-scanning the document, we can implement feature selection. Under the condition that the category result is rarely affected, the extraction of feature subset is needed. The general algorithm is to construct an evaluating function to evaluate the features. As feature set, information gain, cross entropy, mutual information, and odds ratio are usually used.
# The classifier and pattern analysis methods of text data mining are very similar to traditional data mining techniques. The usual evaluative merits are classification accuracy, precision and recall and information score.
# Web mining is an important component of content pipeline for web portals. It is used in data confirmation and validity verification, data integrity and building taxonomies, content management, content generation and opinion mining.[10]
#
# Web content mining in foreign languages[edit]
# Chinese[edit]
# The language code of Chinese words is very complicated compared to that of English. The GB, Big5 and HZ code are common Chinese word codes in web documents. Before text mining, one needs to identify the code standard of the HTML documents and transform it into inner code, then use other data mining techniques to find useful knowledge and useful patterns.
#
# See also[edit]
# Web intelligence
# Web analytics
# Web scraping
# Wikipedia:Data mining Wikipedia
# References[edit]
#
#
# ^ Galitsky B, Dobrocsi G, de la Rosa JL, Kuznetsov SO.  Using generalization of syntactic parse trees for taxonomy capture on the web. ICCS. 2011;8323.
#
# ^ Weichbroth et al.
#
# ^ Ngu, Anne; Kitsuregawa, Masaru; Chung, Jen-Yao; Neuhold, Erich; Sheng, Quan (2005). Web Information Systems Engineering - WISE 2005. Berlin: Springer. p. 15. ISBN 9783540300175.
#
# ^ Bauknecht, Kurt; Madria, Sanjay; Pernul, Gunther (2000). Electronic Commerce and Web Technologies: First International Conference, EC-Web 2000 London, UK, September 4-6, 2000 Proceedings. Berlin: Springer. p. 165. ISBN 978-3540679813.
#
# ^ Scime, Anthony (2005). Web Mining: Applications and Techniques. Hershey, PA: Idea Group Publishing. p. 282. ISBN 978-1591404149.
#
# ^ a b c Lita van Wel & Lambèr Royakkers (2004). "Ethical issues in web data mining" (PDF). Ethical Issues in Web Data Mining..
#
# ^ Kirsten Wahlstrom; John F. Roddick; Vladimir Estivill-Castro; Denise de Vries (2007). "Legal and Technical Issues of Privacy Preservation in Data Mining" (PDF). Legal and Technical Issues of Privacy Preservation in Data Mining..
#
# ^ Wang, Yan. "Web Mining and Knowledge Discovery of Usage Patterns".
#
# ^ Kosala, Raymond; Hendrik Blockeel (July 2000). "Web Mining Research: A Survey". SIGKDD Explorations. 2 (1). arXiv:cs.LG/0011033.
#
# ^ Galitsky B, Dobrocsi G, de la Rosa JL, Kuznetsov SO.  Using generalization of syntactic parse trees for taxonomy capture on the web. ICCS. 2011;8323.
#
#
# Resources[edit]
# This article includes a list of references, but its sources remain unclear because it has insufficient inline citations. Please help to improve this article by introducing more precise citations. (September 2009) (Learn how and when to remove this template message)
# External links[edit]
# The Future of Web Sites = Web Services – (with a section on web scraping)
# Books[edit]
# Zdravko Markov, Daniel T. Larose "Data Mining the Web: Uncovering Patterns in Web Content, Structure, and Usage", Wiley, 2007
# Jesus Mena, "Data Mining Your Website", Digital Press, 1999
# Soumen Chakrabarti, "Mining the Web: Analysis of Hypertext and Semi Structured Data", Morgan Kaufmann, 2002
# Bing Liu, "Web Data Mining: Exploring Hyperlinks, Contents and Usage Data", Springer, 2007
# Advances in Web Mining and Web Usage Analysis 2005 - revised papers from 7 th workshop on Knowledge Discovery on the Web, Olfa Nasraoui, Osmar Zaiane, Myra Spiliopoulou, Bamshad Mobasher, Philip Yu, Brij Masand, Eds., Springer Lecture Notes in Artificial Intelligence, LNAI 4198, 2006
# Web Mining and Web Usage Analysis 2004 - revised papers from 6 th workshop on Knowledge Discovery on the Web, Bamshad Mobasher, Olfa Nasraoui, Bing Liu, Brij Masand, Eds., Springer Lecture Notes in Artificial Intelligence, 2006
# Mike Thelwall, "Link Analysis: An Information Science Approach", 2004, Academic Press
# Bibliographic references[edit]
# Baraglia, R. Silvestri, F. (2007) "Dynamic personalization of web sites without user intervention", In Communications of the ACM 50(2): 63-67
# Cooley, R. Mobasher, B. and Srivastave, J. (1997) “Web Mining: Information and Pattern Discovery on the World Wide Web” In Proceedings of the 9th IEEE International Conference on Tool with Artificial Intelligence
# Cooley, R., Mobasher, B. and Srivastava, J. “Data Preparation for Mining World Wide Web Browsing Patterns”, Journal of Knowledge and Information System, Vol.1, Issue. 1, pp. 5–32, 1999
# Costa, RP and Seco, N. “Hyponymy Extraction and Web Search Behavior Analysis Based On Query Reformulation”, 11th Ibero-American Conference on Artificial Intelligence, 2008 October.
# Kohavi, R., Mason, L. and Zheng, Z. (2004) “Lessons and Challenges from Mining Retail E-commerce Data” Machine Learning, Vol 57, pp. 83–113
# Lillian Clark, I-Hsien Ting, Chris Kimble, Peter Wright, Daniel Kudenko (2006)"Combining ethnographic and clickstream data to identify user Web browsing strategies" Journal of Information Research, Vol. 11 No. 2, January 2006
# Eirinaki, M., Vazirgiannis, M. (2003) "Web Mining for Web Personalization", ACM Transactions on Internet Technology, Vol.3, No.1, February 2003
# Mobasher, B., Cooley, R. and Srivastava, J. (2000) “Automatic Personalization based on web usage Mining” Communications of the ACM, Vol. 43, No.8, pp. 142–151
# Mobasher, B., Dai, H., Luo, T. and Nakagawa, M. (2001) “Effective Personalization Based on Association Rule Discover from Web Usage Data” In Proceedings of WIDM 2001, Atlanta, GA, USA, pp. 9–15
# Nasraoui O., Petenes C.,  "Combining Web Usage Mining and Fuzzy Inference for Website Personalization", in Proc. of WebKDD 2003 – KDD Workshop on Web mining as a Premise to Effective and Intelligent Web Applications, Washington DC, August 2003, p. 37
# Nasraoui O., Frigui H., Joshi A., and Krishnapuram R.,  “Mining Web Access Logs Using Relational Competitive Fuzzy Clustering”, Proceedings of the Eighth International Fuzzy Systems Association Congress, Hsinchu, Taiwan, August 1999
# Nasraoui O., “World Wide Web Personalization,” Invited chapter in “Encyclopedia of Data Mining and Data Warehousing”, J. Wang, Ed, Idea Group, 2005
# Pierrakos, D., Paliouras, G., Papatheodorou, C., Spyropoulos C. D. (2003) “Web usage mining as a tool for personalization: a survey”, User modelling and user adapted interaction journal, Vol.13, Issue 4, pp. 311–372
# I-Hsien Ting, Chris Kimble, Daniel Kudenko (2005) "A Pattern Restore Method for Restoring Missing Patterns in Server Side Clickstream Data"
# I-Hsien Ting, Chris Kimble, Daniel Kudenko (2006) "UBB Mining: Finding Unexpected Browsing Behaviour in Clickstream Data to improve a Web Site’s Design"
# Weichbroth, P., Owoc, M., Pleszkun, M. (2012) "Web User Navigation Patterns Discovery from WWW Server Log Files"
#
#
#
#
# Retrieved from "https://en.wikipedia.org/w/index.php?title=Web_mining&oldid=904363144"
# Categories: Web analyticsData miningWorld Wide WebHidden categories: Articles needing cleanup from June 2009All pages needing cleanupCleanup tagged articles without a reason field from June 2009Wikipedia pages needing cleanup from June 2009Articles to be expanded from June 2015All articles to be expandedArticles using small message boxesArticles lacking in-text citations from September 2009All articles lacking in-text citations
#
#
#
#
# Navigation menu
#
#
# Personal tools
#
# Not logged inTalkContributionsCreate accountLog in
#
#
#
# Namespaces
#
# ArticleTalk
#
#
#
#
# Variants
#
#
#
#
#
#
#
# Views
#
# ReadEditView history
#
#
#
# More
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Navigation
#
#
# Main pageContentsFeatured contentCurrent eventsRandom articleDonate to WikipediaWikipedia store
#
#
#
# Interaction
#
#
# HelpAbout WikipediaCommunity portalRecent changesContact page
#
#
#
# Tools
#
#
# What links hereRelated changesUpload fileSpecial pagesPermanent linkPage informationWikidata itemCite this page
#
#
#
# Print/export
#
#
# Create a bookDownload as PDFPrintable version
#
#
#
# Languages
#
#
# العربيةDeutschEspañolEuskaraفارسیFrançais한국어हिन्दीHrvatskiMagyar日本語PortuguêsРусскийSlovenčinaไทย
# Edit links
#
#
#
#
#
#  This page was last edited on 1 July 2019, at 17:30 (UTC).
# Text is available under the Creative Commons Attribution-ShareAlike License;
# additional terms may apply.  By using this site, you agree to the Terms of Use and Privacy Policy. Wikipedia® is a registered trademark of the Wikimedia Foundation, Inc., a non-profit organization.
#
#
# Privacy policy
# About Wikipedia
# Disclaimers
# Contact Wikipedia
# Developers
# Cookie statement
# Mobile view

# %%
# simple tokenization
import nltk
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text)
print(tokens)
# Out:
# ['Web', 'mining', 'From', 'Wikipedia', ',', 'the', 'free', 'encyclopedia', 'Jump', 'to', 'navigation', 'Jump', 'to', 'search', 'This', 'article', 'may', 'require', 'cleanup', 'to', 'meet', 'Wikipedia', "'s", 'quality', 'standards', '.', 'No', 'cleanup', 'reason', 'has', 'been', 'specified', '.', 'Please', 'help', 'improve', 'this', 'article', 'if', 'you', 'can', '.', '(', 'June', '2009', ')', '(', 'Learn', 'how', 'and', 'when', 'to', 'remove', 'this', 'template', 'message', ')', 'Web', 'mining', 'is', 'the', 'application', 'of', 'data', 'mining', 'techniques', 'to', 'discover', 'patterns', 'from', 'the', 'World', 'Wide', 'Web', '.', 'As', 'the', 'name', 'proposes', ',', 'this', 'is', 'information', 'gathered', 'by', 'mining', 'the', 'web', '.', 'It', 'makes', 'utilization', 'of', 'automated', 'apparatuses', 'to', 'reveal', 'and', 'extricate', 'data', 'from', 'servers', 'and', 'web2', 'reports', ',', 'and', 'it', 'permits', 'organizations', 'to', 'get', 'to', 'both', 'organized', 'and', 'unstructured', 'information', 'from', 'browser', 'activities', ',', 'server', 'logs', ',', 'website', 'and', 'link', 'structure', ',', 'page', 'content', 'and', 'different', 'sources', '.', 'The', 'goal', 'of', 'Web', 'structure', 'mining', 'is', 'to', 'generate', 'structural', 'summary', 'about', 'the', 'Web', 'site', 'and', 'Web', 'page', '.', 'Technically', ',', 'Web', 'content', 'mining', 'mainly', 'focuses', 'on', 'the', 'structure', 'of', 'inner-document', ',', 'while', 'Web', 'structure', 'mining', 'tries', 'to', 'discover', 'the', 'link', 'structure', 'of', 'the', 'hyperlinks', 'at', 'the', 'inter-document', 'level', '.', 'Based', 'on', 'the', 'topology', 'of', 'the', 'hyperlinks', ',', 'Web', 'structure', 'mining', 'will', 'categorize', 'the', 'Web', 'pages', 'and', 'generate', 'the', 'information', ',', 'such', 'as', 'the', 'similarity', 'and', 'relationship', 'between', 'different', 'Web', 'sites', '.', 'Web', 'structure', 'mining', 'can', 'also', 'have', 'another', 'direction', '--', 'discovering', 'the', 'structure', 'of', 'Web', 'document', 'itself', '.', 'This', 'type', 'of', 'structure', 'mining', 'can', 'be', 'used', 'to', 'reveal', 'the', 'structure', '(', 'schema', ')', 'of', 'Web', 'pages', ',', 'this', 'would', 'be', 'good', 'for', 'navigation', 'purpose', 'and', 'make', 'it', 'possible', 'to', 'compare/integrate', 'Web', 'page', 'schemes', '.', 'This', 'type', 'of', 'structure', 'mining', 'will', 'facilitate', 'introducing', 'database', 'techniques', 'for', 'accessing', 'information', 'in', 'Web', 'pages', 'by', 'providing', 'a', 'reference', 'schema', '.', 'Contents', '1', 'Web', 'mining', 'types', '2', 'Web', 'usage', 'mining', '2.1', 'Pros', '2.2', 'Cons', '3', 'Web', 'structure', 'mining', '4', 'Web', 'content', 'mining', '4.1', 'Web', 'content', 'mining', 'in', 'foreign', 'languages', '4.1.1', 'Chinese', '5', 'See', 'also', '6', 'References', '7', 'Resources', '7.1', 'External', 'links', '7.2', 'Books', '7.3', 'Bibliographic', 'references', 'Web', 'mining', 'types', '[', 'edit', ']', 'Web', 'mining', 'can', 'be', 'divided', 'into', 'three', 'different', 'types', '–', 'Web', 'usage', 'mining', ',', 'Web', 'content', 'mining', 'and', 'Web', 'structure', 'mining', '.', 'The', 'general', 'relationship', 'between', 'the', 'categories', 'of', 'Web', 'Mining', 'and', 'objectives', 'of', 'Data', 'Mining', 'Comparison', 'of', 'web', 'mining', 'types', '[', '1', ']', 'Web', 'content', 'Mining', 'Web', 'structure', 'mining', 'Web', 'usage', 'mining', 'IR', 'view', 'DB', 'view', 'View', 'of', 'data', 'Unstructured', 'Structured', 'Semi-structured', 'Web', 'site', 'as', 'DB', 'Link', 'structure', 'Interactivity', 'Main', 'data', 'Text', 'documents', 'Hypertext', 'documents', 'Hypertext', 'documents', 'Link', 'structure', 'Server', 'logs', 'Browser', 'logs', 'Representation', 'Bag', 'of', 'words', ',', 'n-gram', 'terms', 'phrases', ',', 'concepts', 'or', 'ontology', 'Relational', 'Edge', 'labed', 'graph', 'Relational', 'Graph', 'Re ...

# %%
#tokenizer to accept only alphanumeric character
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['Web', 'mining', 'From', 'Wikipedia', 'the', 'free', 'encyclopedia', 'Jump', 'to', 'navigation', 'Jump', 'to', 'search', 'This', 'article', 'may', 'require', 'cleanup', 'to', 'meet', 'Wikipedia', 's', 'quality', 'standards', 'No', 'cleanup', 'reason', 'has', 'been', 'specified', 'Please', 'help', 'improve', 'this', 'article', 'if', 'you', 'can', 'June', '2009', 'Learn', 'how', 'and', 'when', 'to', 'remove', 'this', 'template', 'message', 'Web', 'mining', 'is', 'the', 'application', 'of', 'data', 'mining', 'techniques', 'to', 'discover', 'patterns', 'from', 'the', 'World', 'Wide', 'Web', 'As', 'the', 'name', 'proposes', 'this', 'is', 'information', 'gathered', 'by', 'mining', 'the', 'web', 'It', 'makes', 'utilization', 'of', 'automated', 'apparatuses', 'to', 'reveal', 'and', 'extricate', 'data', 'from', 'servers', 'and', 'web2', 'reports', 'and', 'it', 'permits', 'organizations', 'to', 'get', 'to', 'both', 'organized', 'and', 'unstructured', 'information', 'from', 'browser', 'activities', 'server', 'logs', 'website', 'and', 'link', 'structure', 'page', 'content', 'and', 'different', 'sources', 'The', 'goal', 'of', 'Web', 'structure', 'mining', 'is', 'to', 'generate', 'structural', 'summary', 'about', 'the', 'Web', 'site', 'and', 'Web', 'page', 'Technically', 'Web', 'content', 'mining', 'mainly', 'focuses', 'on', 'the', 'structure', 'of', 'inner', 'document', 'while', 'Web', 'structure', 'mining', 'tries', 'to', 'discover', 'the', 'link', 'structure', 'of', 'the', 'hyperlinks', 'at', 'the', 'inter', 'document', 'level', 'Based', 'on', 'the', 'topology', 'of', 'the', 'hyperlinks', 'Web', 'structure', 'mining', 'will', 'categorize', 'the', 'Web', 'pages', 'and', 'generate', 'the', 'information', 'such', 'as', 'the', 'similarity', 'and', 'relationship', 'between', 'different', 'Web', 'sites', 'Web', 'structure', 'mining', 'can', 'also', 'have', 'another', 'direction', 'discovering', 'the', 'structure', 'of', 'Web', 'document', 'itself', 'This', 'type', 'of', 'structure', 'mining', 'can', 'be', 'used', 'to', 'reveal', 'the', 'structure', 'schema', 'of', 'Web', 'pages', 'this', 'would', 'be', 'good', 'for', 'navigation', 'purpose', 'and', 'make', 'it', 'possible', 'to', 'compare', 'integrate', 'Web', 'page', 'schemes', 'This', 'type', 'of', 'structure', 'mining', 'will', 'facilitate', 'introducing', 'database', 'techniques', 'for', 'accessing', 'information', 'in', 'Web', 'pages', 'by', 'providing', 'a', 'reference', 'schema', 'Contents', '1', 'Web', 'mining', 'types', '2', 'Web', 'usage', 'mining', '2', '1', 'Pros', '2', '2', 'Cons', '3', 'Web', 'structure', 'mining', '4', 'Web', 'content', 'mining', '4', '1', 'Web', 'content', 'mining', 'in', 'foreign', 'languages', '4', '1', '1', 'Chinese', '5', 'See', 'also', '6', 'References', '7', 'Resources', '7', '1', 'External', 'links', '7', '2', 'Books', '7', '3', 'Bibliographic', 'references', 'Web', 'mining', 'types', 'edit', 'Web', 'mining', 'can', 'be', 'divided', 'into', 'three', 'different', 'types', 'Web', 'usage', 'mining', 'Web', 'content', 'mining', 'and', 'Web', 'structure', 'mining', 'The', 'general', 'relationship', 'between', 'the', 'categories', 'of', 'Web', 'Mining', 'and', 'objectives', 'of', 'Data', 'Mining', 'Comparison', 'of', 'web', 'mining', 'types', '1', 'Web', 'content', 'Mining', 'Web', 'structure', 'mining', 'Web', 'usage', 'mining', 'IR', 'view', 'DB', 'view', 'View', 'of', 'data', 'Unstructured', 'Structured', 'Semi', 'structured', 'Web', 'site', 'as', 'DB', 'Link', 'structure', 'Interactivity', 'Main', 'data', 'Text', 'documents', 'Hypertext', 'documents', 'Hypertext', 'documents', 'Link', 'structure', 'Server', 'logs', 'Browser', 'logs', 'Representation', 'Bag', 'of', 'words', 'n', 'gram', 'terms', 'phrases', 'concepts', 'or', 'ontology', 'Relational', 'Edge', 'labed', 'graph', 'Relational', 'Graph', 'Relational', 'table', 'Graph', 'Method', 'Machine', 'learning', 'Statistical', 'including', 'NLP', 'Proprietary', 'algorithms', 'Association', 'rules', 'Proprie ...

# %%
#applying stopword removal
from nltk.corpus import stopwords
stopwords = list(nltk.corpus.stopwords.words('english'))
words = [word for word in tokens if word not in stopwords]
print(words)
# Out:
# ['Web', 'mining', 'From', 'Wikipedia', 'free', 'encyclopedia', 'Jump', 'navigation', 'Jump', 'search', 'This', 'article', 'may', 'require', 'cleanup', 'meet', 'Wikipedia', 'quality', 'standards', 'No', 'cleanup', 'reason', 'specified', 'Please', 'help', 'improve', 'article', 'June', '2009', 'Learn', 'remove', 'template', 'message', 'Web', 'mining', 'application', 'data', 'mining', 'techniques', 'discover', 'patterns', 'World', 'Wide', 'Web', 'As', 'name', 'proposes', 'information', 'gathered', 'mining', 'web', 'It', 'makes', 'utilization', 'automated', 'apparatuses', 'reveal', 'extricate', 'data', 'servers', 'web2', 'reports', 'permits', 'organizations', 'get', 'organized', 'unstructured', 'information', 'browser', 'activities', 'server', 'logs', 'website', 'link', 'structure', 'page', 'content', 'different', 'sources', 'The', 'goal', 'Web', 'structure', 'mining', 'generate', 'structural', 'summary', 'Web', 'site', 'Web', 'page', 'Technically', 'Web', 'content', 'mining', 'mainly', 'focuses', 'structure', 'inner', 'document', 'Web', 'structure', 'mining', 'tries', 'discover', 'link', 'structure', 'hyperlinks', 'inter', 'document', 'level', 'Based', 'topology', 'hyperlinks', 'Web', 'structure', 'mining', 'categorize', 'Web', 'pages', 'generate', 'information', 'similarity', 'relationship', 'different', 'Web', 'sites', 'Web', 'structure', 'mining', 'also', 'another', 'direction', 'discovering', 'structure', 'Web', 'document', 'This', 'type', 'structure', 'mining', 'used', 'reveal', 'structure', 'schema', 'Web', 'pages', 'would', 'good', 'navigation', 'purpose', 'make', 'possible', 'compare', 'integrate', 'Web', 'page', 'schemes', 'This', 'type', 'structure', 'mining', 'facilitate', 'introducing', 'database', 'techniques', 'accessing', 'information', 'Web', 'pages', 'providing', 'reference', 'schema', 'Contents', '1', 'Web', 'mining', 'types', '2', 'Web', 'usage', 'mining', '2', '1', 'Pros', '2', '2', 'Cons', '3', 'Web', 'structure', 'mining', '4', 'Web', 'content', 'mining', '4', '1', 'Web', 'content', 'mining', 'foreign', 'languages', '4', '1', '1', 'Chinese', '5', 'See', 'also', '6', 'References', '7', 'Resources', '7', '1', 'External', 'links', '7', '2', 'Books', '7', '3', 'Bibliographic', 'references', 'Web', 'mining', 'types', 'edit', 'Web', 'mining', 'divided', 'three', 'different', 'types', 'Web', 'usage', 'mining', 'Web', 'content', 'mining', 'Web', 'structure', 'mining', 'The', 'general', 'relationship', 'categories', 'Web', 'Mining', 'objectives', 'Data', 'Mining', 'Comparison', 'web', 'mining', 'types', '1', 'Web', 'content', 'Mining', 'Web', 'structure', 'mining', 'Web', 'usage', 'mining', 'IR', 'view', 'DB', 'view', 'View', 'data', 'Unstructured', 'Structured', 'Semi', 'structured', 'Web', 'site', 'DB', 'Link', 'structure', 'Interactivity', 'Main', 'data', 'Text', 'documents', 'Hypertext', 'documents', 'Hypertext', 'documents', 'Link', 'structure', 'Server', 'logs', 'Browser', 'logs', 'Representation', 'Bag', 'words', 'n', 'gram', 'terms', 'phrases', 'concepts', 'ontology', 'Relational', 'Edge', 'labed', 'graph', 'Relational', 'Graph', 'Relational', 'table', 'Graph', 'Method', 'Machine', 'learning', 'Statistical', 'including', 'NLP', 'Proprietary', 'algorithms', 'Association', 'rules', 'Proprietary', 'algorithms', 'Machine', 'learning', 'Statistical', 'Association', 'rules', 'Application', 'categories', 'Categorization', 'Clustering', 'Finding', 'extract', 'rules', 'Finding', 'patterns', 'text', 'Finding', 'frequent', 'sub', 'structures', 'Web', 'site', 'schema', 'discovery', 'Categorization', 'Clustering', 'Site', 'construction', 'Adaptation', 'management', 'Web', 'usage', 'mining', 'edit', 'Web', 'Usage', 'Mining', 'application', 'data', 'mining', 'techniques', 'discover', 'interesting', 'usage', 'patterns', 'Web', 'data', 'order', 'understand', 'better', 'serve', 'needs', 'Web', 'based', 'applications', 'Usage', 'data', 'captures', 'identity', 'origin', 'Web', 'users', 'along', 'browsing', 'behavior', 'Web', 'sit ...

# %%
#display the number of words and term frequency of each word present in 
#them after applying stop word removal.
fdist = nltk.FreqDist(words)
for word, frequency in fdist.most_common():
    print('{}  ==> {}'.format(word, frequency))
# Out:
# Web  ==> 94
# mining  ==> 63
# data  ==> 39
# web  ==> 31
# structure  ==> 27
# Mining  ==> 27
# The  ==> 21
# Data  ==> 20
# usage  ==> 18
# information  ==> 17
# content  ==> 15
# edit  ==> 14
# page  ==> 12
# 1  ==> 12
# This  ==> 11
# documents  ==> 11
# Usage  ==> 10
# user  ==> 10
# patterns  ==> 9
# site  ==> 9
# 2  ==> 9
# techniques  ==> 8
# used  ==> 8
# based  ==> 8
# Wikipedia  ==> 7
# Wide  ==> 7
# document  ==> 7
# links  ==> 7
# customer  ==> 7
# June  ==> 6
# application  ==> 6
# World  ==> 6
# different  ==> 6
# 4  ==> 6
# 6  ==> 6
# 7  ==> 6
# view  ==> 6
# text  ==> 6
# applications  ==> 6
# technology  ==> 6
# might  ==> 6
# Analysis  ==> 6
# obtained  ==> 6
# Information  ==> 6
# B  ==> 6
# 2005  ==> 6
# Mobasher  ==> 6
# R  ==> 6
# Vol  ==> 6
# logs  ==> 5
# pages  ==> 5
# also  ==> 5
# Server  ==> 5
# words  ==> 5
# graph  ==> 5
# algorithms  ==> 5
# needs  ==> 5
# Privacy  ==> 5
# use  ==> 5
# node  ==> 5
# Springer  ==> 5
# 2000  ==> 5
# Discovery  ==> 5
# Patterns  ==> 5
# Nasraoui  ==> 5
# 2006  ==> 5
# pp  ==> 5
# M  ==> 5
# 2003  ==> 5
# Personalization  ==> 5
# article  ==> 4
# cleanup  ==> 4
# No  ==> 4
# discover  ==> 4
# It  ==> 4
# structural  ==> 4
# hyperlinks  ==> 4
# database  ==> 4
# types  ==> 4
# 3  ==> 4
# Chinese  ==> 4
# categories  ==> 4
# structured  ==> 4
# Relational  ==> 4
# Association  ==> 4
# Finding  ==> 4
# better  ==> 4
# features  ==> 4
# A  ==> 4
# feature  ==> 4
# one  ==> 4
# two  ==> 4
# tools  ==> 4
# particular  ==> 4
# specific  ==> 4
# knowledge  ==> 4
# personal  ==> 4
# individual  ==> 4
# de  ==> 4
# semi  ==> 4
# code  ==> 4
# p  ==> 4
# Proceedings  ==> 4
# 2004  ==> 4
# 2007  ==> 4
# Knowledge  ==> 4
# citations  ==> 4
# Daniel  ==> 4
# Artificial  ==> 4
# Intelligence  ==> 4
# J  ==> 4
# search  ==> 3
# help  ==> 3
# improve  ==> 3
# message  ==> 3
# As  ==> 3
# makes  ==> 3
# unstructured  ==> 3
# server  ==> 3
# sources  ==> 3
# Based  ==> 3
# categorize  ==> 3
# relationship  ==> 3
# type  ==> 3
# schema  ==> 3
# make  ==> 3
# 5  ==> 3
# references  ==> 3
# View  ==> 3
# Link  ==> 3
# Hypertext  ==> 3
# Machine  ==> 3
# rules  ==> 3
# Application  ==> 3
# Clustering  ==> 3
# structures  ==> 3
# management  ==> 3
# users  ==> 3
# considered  ==> 3
# commerce  ==> 3
# kinds  ==> 3
# events  ==> 3
# defined  ==> 3
# applied  ==> 3
# using  ==> 3
# find  ==> 3
# customers  ==> 3
# They  ==> 3
# profiles  ==> 3
# personalization  ==> 3
# additional  ==> 3
# These  ==> 3
# privacy  ==> 3
# without  ==> 3
# anonymous  ==> 3
# companies  ==> 3
# release  ==> 3
# result  ==> 3
# attributes  ==> 3
# identify  ==> 3
# HTML  ==> 3
# number  ==> 3
# algorithm  ==> 3
# useful  ==> 3
# organization  ==> 3
# provide  ==> 3
# G  ==> 3
# Using  ==> 3
# ISBN  ==> 3
# International  ==> 3
# Conference  ==> 3
# September  ==> 3
# Issues  ==> 3
# 1999  ==> 3
# In  ==> 3
# ACM  ==> 3
# Cooley  ==> 3
# I  ==> 3
# Hsien  ==> 3
# Ting  ==> 3
# Chris  ==> 3
# Kimble  ==> 3
# Kudenko  ==> 3
# O  ==> 3
# C  ==> 3
# Fuzzy  ==> 3
# Navigation  ==> 3
# needing  ==> 3
# articles  ==> 3
# Jump  ==> 2
# navigation  ==> 2
# may  ==> 2
# require  ==> 2
# standards  ==> 2
# reason  ==> 2
# Please  ==> 2
# 2009  ==> 2
# Learn  ==> 2
# remove  ==> 2
# template  ==> 2
# name  ==> 2
# automated  ==> 2
# reveal  ==> 2
# servers  ==> 2
# permits  ==> 2
# activities  ==> 2
# website  ==> 2
# link  ==> 2
# generate  ==> 2
# inner  ==> 2
# tries  ==> 2
# level  ==> 2
# sites  ==> 2
# purpose  ==> 2
# introducing  ==> 2
# providing  ==> 2
# reference  ==> 2
# Contents  ==> 2
# Pros  ==> 2
# Cons  ==> 2
# foreign  ==> 2
# languages  ==> 2
# See  ==> 2
# References  ==> 2
# Resources  ==> 2
# External  ==> 2
# Books  ==> 2
# Bibliographic  ==> 2
# divided  ==> 2
# general  ==> 2
# DB  ==> 2
# Structured  ==> 2
# Semi  ==> 2
# Main  ==> 2
# Text  ==> 2
# terms  ==> 2
# Graph  ==> 2
# Method  ==> 2
# learning  ==> 2
# Statistical  ==> 2
# including  ==> 2
# Proprietary  ==> 2
# Categorization  ==> 2
# extract  ==> 2
# discovery  ==> 2
# Site  ==> 2
# order  ==> 2
# browsing  ==> 2
# behavior  ==> 2
# collected  ==> 2
# includes  ==> 2
# address  ==> 2
# access  ==> 2
# time  ==> 2
# e  ==> 2
# log  ==> 2
# thus  ==> 2
# systems  ==> 2
# Costa  ==> 2
# Seco  ==> 2
# semantic  ==> 2
# given  ==> 2
# essentially  ==> 2
# agencies  ==> 2
# results  ==> 2
# higher  ==> 2
# trade  ==> 2
# capability  ==> 2
# Companies  ==> 2
# retain  ==> 2
# target  ==> 2
# company  ==> 2
# More  ==> 2
# benefits  ==> 2
# model  ==> 2
# pattern  ==> 2
# process  ==> 2
# traditional  ==> 2
# validity  ==> 2
# There  ==> 2
# issues  ==> 2
# ethical  ==> 2
# made  ==> 2
# judging  ==> 2
# characteristics  ==> 2
# merits  ==> 2
# important  ==> 2
# trend  ==> 2
# controversial  ==> 2
# like  ==> 2
# race  ==> 2
# religion  ==> 2
# sexual  ==> 2
# orientation  ==> 2
# section  ==> 2
# hyperlink  ==> 2
# component  ==> 2
# analysis  ==> 2
# degree  ==> 2
# pointing  ==> 2
# Techniques  ==> 2
# Google  ==> 2
# rank  ==> 2
# extraction  ==> 2
# Internet  ==> 2
# intelligent  ==> 2
# retrieval  ==> 2
# available  ==> 2
# autonomously  ==> 2
# 8  ==> 2
# 9  ==> 2
# works  ==> 2
# single  ==> 2
# represent  ==> 2
# word  ==> 2
# representation  ==> 2
# transform  ==> 2
# vector  ==> 2
# space  ==> 2
# Frequency  ==> 2
# By  ==> 2
# scraping  ==> 2
# Galitsky  ==> 2
# Dobrocsi  ==> 2
# la  ==> 2
# Rosa  ==> 2
# JL  ==> 2
# Kuznetsov  ==> 2
# SO  ==> 2
# generalization  ==> 2
# syntactic  ==> 2
# parse  ==> 2
# trees  ==> 2
# taxonomy  ==> 2
# capture  ==> 2
# ICCS  ==> 2
# 2011  ==> 2
# 8323  ==> 2
# Weichbroth  ==> 2
# Systems  ==> 2
# Berlin  ==> 2
# 15  ==> 2
# 978  ==> 2
# Applications  ==> 2
# Idea  ==> 2
# Group  ==> 2
# Ethical  ==> 2
# PDF  ==> 2
# F  ==> 2
# Legal  ==> 2
# Technical  ==> 2
# Preservation  ==> 2
# Wang  ==> 2
# July  ==> 2
# Research  ==> 2
# T  ==> 2
# Website  ==> 2
# Press  ==> 2
# Bing  ==> 2
# Liu  ==> 2
# revised  ==> 2
# papers  ==> 2
# th  ==> 2
# workshop  ==> 2
# Olfa  ==> 2
# Bamshad  ==> 2
# Brij  ==> 2
# Masand  ==> 2
# Eds  ==> 2
# Lecture  ==> 2
# Notes  ==> 2
# Communications  ==> 2
# Pattern  ==> 2
# Srivastava  ==> 2
# Browsing  ==> 2
# Journal  ==> 2
# Issue  ==> 2
# Search  ==> 2
# Combining  ==> 2
# H  ==> 2
# 2001  ==> 2
# Effective  ==> 2
# August  ==> 2
# D  ==> 2
# User  ==> 2
# Clickstream  ==> 2
# 2009All  ==> 2
# lacking  ==> 2
# From  ==> 1
# free  ==> 1
# encyclopedia  ==> 1
# meet  ==> 1
# quality  ==> 1
# specified  ==> 1
# proposes  ==> 1
# gathered  ==> 1
# utilization  ==> 1
# apparatuses  ==> 1
# extricate  ==> 1
# web2  ==> 1
# reports  ==> 1
# organizations  ==> 1
# get  ==> 1
# organized  ==> 1
# browser  ==> 1
# goal  ==> 1
# summary  ==> 1
# Technically  ==> 1
# mainly  ==> 1
# focuses  ==> 1
# inter  ==> 1
# topology  ==> 1
# similarity  ==> 1
# another  ==> 1
# direction  ==> 1
# discovering  ==> 1
# would  ==> 1
# good  ==> 1
# possible  ==> 1
# compare  ==> 1
# integrate  ==> 1
# schemes  ==> 1
# facilitate  ==> 1
# accessing  ==> 1
# three  ==> 1
# objectives  ==> 1
# Comparison  ==> 1
# IR  ==> 1
# Unstructured  ==> 1
# Interactivity  ==> 1
# Browser  ==> 1
# Representation  ==> 1
# Bag  ==> 1
# n  ==> 1
# gram  ==> 1
# phrases  ==> 1
# concepts  ==> 1
# ontology  ==> 1
# Edge  ==> 1
# labed  ==> 1
# table  ==> 1
# NLP  ==> 1
# frequent  ==> 1
# sub  ==> 1
# construction  ==> 1
# Adaptation  ==> 1
# interesting  ==> 1
# understand  ==> 1
# serve  ==> 1
# captures  ==> 1
# identity  ==> 1
# origin  ==> 1
# along  ==> 1
# classified  ==> 1
# depending  ==> 1
# kind  ==> 1
# Typical  ==> 1
# IP  ==> 1
# Commercial  ==> 1
# significant  ==> 1
# enable  ==> 1
# built  ==> 1
# top  ==> 1
# little  ==> 1
# effort  ==> 1
# key  ==> 1
# ability  ==> 1
# track  ==> 1
# various  ==> 1
# business  ==> 1
# Level  ==> 1
# New  ==> 1
# logging  ==> 1
# turned  ==> 1
# generating  ==> 1
# histories  ==> 1
# specially  ==> 1
# Many  ==> 1
# end  ==> 1
# combination  ==> 1
# Studies  ==> 1
# related  ==> 1
# work  ==> 1
# concerned  ==> 1
# areas  ==> 1
# constraint  ==> 1
# developed  ==> 1
# software  ==> 1
# demonstrated  ==> 1
# hyponymy  ==> 1
# relationships  ==> 1
# community  ==> 1
# many  ==> 1
# advantages  ==> 1
# attractive  ==> 1
# corporations  ==> 1
# government  ==> 1
# enabled  ==> 1
# personalized  ==> 1
# marketing  ==> 1
# eventually  ==> 1
# volumes  ==> 1
# Government  ==> 1
# classify  ==> 1
# threats  ==> 1
# fight  ==> 1
# terrorism  ==> 1
# predicting  ==> 1
# benefit  ==> 1
# society  ==> 1
# identifying  ==> 1
# criminal  ==> 1
# establish  ==> 1
# understanding  ==> 1
# reacting  ==> 1
# faster  ==> 1
# attract  ==> 1
# save  ==> 1
# production  ==> 1
# costs  ==> 1
# utilizing  ==> 1
# acquired  ==> 1
# insight  ==> 1
# requirements  ==> 1
# increase  ==> 1
# profitability  ==> 1
# pricing  ==> 1
# created  ==> 1
# even  ==> 1
# default  ==> 1
# competitor  ==> 1
# try  ==> 1
# promotional  ==> 1
# offers  ==> 1
# reducing  ==> 1
# risk  ==> 1
# losing  ==> 1
# particularly  ==> 1
# area  ==> 1
# outlined  ==> 1
# frameworks  ==> 1
# Probabilistic  ==> 1
# Latent  ==> 1
# Semantic  ==> 1
# offer  ==> 1
# provides  ==> 1
# relevant  ==> 1
# collaborative  ==> 1
# recommendation  ==> 1
# models  ==> 1
# demonstrate  ==> 1
# problems  ==> 1
# associated  ==> 1
# biases  ==> 1
# questions  ==> 1
# regarding  ==> 1
# since  ==> 1
# subjective  ==> 1
# degrade  ==> 1
# elements  ==> 1
# unique  ==> 1
# show  ==> 1
# include  ==> 1
# way  ==> 1
# interpreting  ==> 1
# analyzing  ==> 1
# reasoning  ==> 1
# phase  ==> 1
# create  ==> 1
# nature  ==> 1
# cause  ==> 1
# concerns  ==> 1
# criticized  ==> 1
# issue  ==> 1
# involving  ==> 1
# invasion  ==> 1
# lost  ==> 1
# concerning  ==> 1
# disseminated  ==> 1
# especially  ==> 1
# occurs  ==> 1
# consent  ==> 1
# analyzed  ==> 1
# clustered  ==> 1
# form  ==> 1
# clustering  ==> 1
# Thus  ==> 1
# individualize  ==> 1
# mouse  ==> 1
# clicks  ==> 1
# De  ==> 1
# individualization  ==> 1
# tendency  ==> 1
# treating  ==> 1
# people  ==> 1
# basis  ==> 1
# group  ==> 1
# instead  ==> 1
# Another  ==> 1
# concern  ==> 1
# collecting  ==> 1
# totally  ==> 1
# purposes  ==> 1
# violates  ==> 1
# interests  ==> 1
# growing  ==> 1
# selling  ==> 1
# commodity  ==> 1
# encourages  ==> 1
# owners  ==> 1
# increased  ==> 1
# amount  ==> 1
# captured  ==> 1
# traded  ==> 1
# increasing  ==> 1
# likeliness  ==> 1
# invaded  ==> 1
# buy  ==> 1
# obliged  ==> 1
# authors  ==> 1
# legally  ==> 1
# responsible  ==> 1
# contents  ==> 1
# inaccuracies  ==> 1
# serious  ==> 1
# lawsuits  ==> 1
# law  ==> 1
# preventing  ==> 1
# trading  ==> 1
# Some  ==> 1
# sex  ==> 1
# individuals  ==> 1
# practices  ==> 1
# anti  ==> 1
# discrimination  ==> 1
# legislation  ==> 1
# hard  ==> 1
# strong  ==> 1
# rule  ==> 1
# could  ==> 1
# denial  ==> 1
# service  ==> 1
# privilege  ==> 1
# Right  ==> 1
# situation  ==> 1
# avoided  ==> 1
# high  ==> 1
# maintained  ==> 1
# cannot  ==> 1
# traced  ==> 1
# back  ==> 1
# look  ==> 1
# poses  ==> 1
# threat  ==> 1
# however  ==> 1
# inferred  ==> 1
# combining  ==> 1
# separate  ==> 1
# unscrupulous  ==> 1
# expansion  ==> 1
# You  ==> 1
# adding  ==> 1
# 2015  ==> 1
# uses  ==> 1
# theory  ==> 1
# analyze  ==> 1
# connection  ==> 1
# According  ==> 1
# Extracting  ==> 1
# connects  ==> 1
# location  ==> 1
# tree  ==> 1
# describe  ==> 1
# XML  ==> 1
# tag  ==> 1
# terminology  ==> 1
# directed  ==> 1
# representing  ==> 1
# edge  ==> 1
# generated  ==> 1
# PageRank  ==> 1
# founder  ==> 1
# Larry  ==> 1
# Page  ==> 1
# decided  ==> 1
# integration  ==> 1
# heterogeneity  ==> 1
# lack  ==> 1
# much  ==> 1
# ever  ==> 1
# expanding  ==> 1
# hypertext  ==> 1
# indexing  ==> 1
# Lycos  ==> 1
# Alta  ==> 1
# Vista  ==> 1
# WebCrawler  ==> 1
# Aliweb  ==> 1
# MetaCrawler  ==> 1
# others  ==> 1
# comfort  ==> 1
# generally  ==> 1
# filter  ==> 1
# interpret  ==> 1
# factors  ==> 1
# prompted  ==> 1
# researchers  ==> 1
# develop  ==> 1
# agents  ==> 1
# well  ==> 1
# extend  ==> 1
# agent  ==> 1
# approach  ==> 1
# involves  ==> 1
# development  ==> 1
# sophisticated  ==> 1
# AI  ==> 1
# act  ==> 1
# behalf  ==> 1
# organize  ==> 1
# differentiated  ==> 1
# points  ==> 1
# Retrieval  ==> 1
# Database  ==> 1
# summarized  ==> 1
# research  ==> 1
# done  ==> 1
# shows  ==> 1
# researches  ==> 1
# bag  ==> 1
# statistics  ==> 1
# isolation  ==> 1
# take  ==> 1
# found  ==> 1
# training  ==> 1
# corpus  ==> 1
# For  ==> 1
# utilize  ==> 1
# inside  ==> 1
# utilized  ==> 1
# querying  ==> 1
# always  ==> 1
# infer  ==> 1
# become  ==> 1
# several  ==> 1
# ways  ==> 1
# typically  ==> 1
# constitute  ==> 1
# whole  ==> 1
# realize  ==> 1
# importance  ==> 1
# To  ==> 1
# resolve  ==> 1
# tf  ==> 1
# idf  ==> 1
# Term  ==> 1
# Times  ==> 1
# Inverse  ==> 1
# Document  ==> 1
# introduced  ==> 1
# multi  ==> 1
# scanning  ==> 1
# implement  ==> 1
# selection  ==> 1
# Under  ==> 1
# condition  ==> 1
# category  ==> 1
# rarely  ==> 1
# affected  ==> 1
# subset  ==> 1
# needed  ==> 1
# construct  ==> 1
# evaluating  ==> 1
# function  ==> 1
# evaluate  ==> 1
# set  ==> 1
# gain  ==> 1
# cross  ==> 1
# entropy  ==> 1
# mutual  ==> 1
# odds  ==> 1
# ratio  ==> 1
# usually  ==> 1
# classifier  ==> 1
# methods  ==> 1
# similar  ==> 1
# usual  ==> 1
# evaluative  ==> 1
# classification  ==> 1
# accuracy  ==> 1
# precision  ==> 1
# recall  ==> 1
# score  ==> 1
# pipeline  ==> 1
# portals  ==> 1
# confirmation  ==> 1
# verification  ==> 1
# integrity  ==> 1
# building  ==> 1
# taxonomies  ==> 1
# generation  ==> 1
# opinion  ==> 1
# 10  ==> 1
# language  ==> 1
# complicated  ==> 1
# compared  ==> 1
# English  ==> 1
# GB  ==> 1
# Big5  ==> 1
# HZ  ==> 1
# common  ==> 1
# codes  ==> 1
# Before  ==> 1
# standard  ==> 1
# intelligence  ==> 1
# analytics  ==> 1
# et  ==> 1
# al  ==> 1
# Ngu  ==> 1
# Anne  ==> 1
# Kitsuregawa  ==> 1
# Masaru  ==> 1
# Chung  ==> 1
# Jen  ==> 1
# Yao  ==> 1
# Neuhold  ==> 1
# Erich  ==> 1
# Sheng  ==> 1
# Quan  ==> 1
# Engineering  ==> 1
# WISE  ==> 1
# 9783540300175  ==> 1
# Bauknecht  ==> 1
# Kurt  ==> 1
# Madria  ==> 1
# Sanjay  ==> 1
# Pernul  ==> 1
# Gunther  ==> 1
# Electronic  ==> 1
# Commerce  ==> 1
# Technologies  ==> 1
# First  ==> 1
# EC  ==> 1
# London  ==> 1
# UK  ==> 1
# 165  ==> 1
# 3540679813  ==> 1
# Scime  ==> 1
# Anthony  ==> 1
# Hershey  ==> 1
# PA  ==> 1
# Publishing  ==> 1
# 282  ==> 1
# 1591404149  ==> 1
# b  ==> 1
# c  ==> 1
# Lita  ==> 1
# van  ==> 1
# Wel  ==> 1
# Lambèr  ==> 1
# Royakkers  ==> 1
# Kirsten  ==> 1
# Wahlstrom  ==> 1
# John  ==> 1
# Roddick  ==> 1
# Vladimir  ==> 1
# Estivill  ==> 1
# Castro  ==> 1
# Denise  ==> 1
# Vries  ==> 1
# Yan  ==> 1
# Kosala  ==> 1
# Raymond  ==> 1
# Hendrik  ==> 1
# Blockeel  ==> 1
# Survey  ==> 1
# SIGKDD  ==> 1
# Explorations  ==> 1
# arXiv  ==> 1
# cs  ==> 1
# LG  ==> 1
# 0011033  ==> 1
# list  ==> 1
# remain  ==> 1
# unclear  ==> 1
# insufficient  ==> 1
# inline  ==> 1
# precise  ==> 1
# Future  ==> 1
# Sites  ==> 1
# Services  ==> 1
# Zdravko  ==> 1
# Markov  ==> 1
# Larose  ==> 1
# Uncovering  ==> 1
# Content  ==> 1
# Structure  ==> 1
# Wiley  ==> 1
# Jesus  ==> 1
# Mena  ==> 1
# Your  ==> 1
# Digital  ==> 1
# Soumen  ==> 1
# Chakrabarti  ==> 1
# Morgan  ==> 1
# Kaufmann  ==> 1
# 2002  ==> 1
# Exploring  ==> 1
# Hyperlinks  ==> 1
# Advances  ==> 1
# Osmar  ==> 1
# Zaiane  ==> 1
# Myra  ==> 1
# Spiliopoulou  ==> 1
# Philip  ==> 1
# Yu  ==> 1
# LNAI  ==> 1
# 4198  ==> 1
# Mike  ==> 1
# Thelwall  ==> 1
# An  ==> 1
# Science  ==> 1
# Approach  ==> 1
# Academic  ==> 1
# Baraglia  ==> 1
# Silvestri  ==> 1
# Dynamic  ==> 1
# intervention  ==> 1
# 50  ==> 1
# 63  ==> 1
# 67  ==> 1
# Srivastave  ==> 1
# 1997  ==> 1
# 9th  ==> 1
# IEEE  ==> 1
# Tool  ==> 1
# Preparation  ==> 1
# System  ==> 1
# 32  ==> 1
# RP  ==> 1
# N  ==> 1
# Hyponymy  ==> 1
# Extraction  ==> 1
# Behavior  ==> 1
# On  ==> 1
# Query  ==> 1
# Reformulation  ==> 1
# 11th  ==> 1
# Ibero  ==> 1
# American  ==> 1
# 2008  ==> 1
# October  ==> 1
# Kohavi  ==> 1
# Mason  ==> 1
# L  ==> 1
# Zheng  ==> 1
# Z  ==> 1
# Lessons  ==> 1
# Challenges  ==> 1
# Retail  ==> 1
# E  ==> 1
# Learning  ==> 1
# 57  ==> 1
# 83  ==> 1
# 113  ==> 1
# Lillian  ==> 1
# Clark  ==> 1
# Peter  ==> 1
# Wright  ==> 1
# ethnographic  ==> 1
# clickstream  ==> 1
# strategies  ==> 1
# 11  ==> 1
# January  ==> 1
# Eirinaki  ==> 1
# Vazirgiannis  ==> 1
# Transactions  ==> 1
# Technology  ==> 1
# February  ==> 1
# Automatic  ==> 1
# 43  ==> 1
# 142  ==> 1
# 151  ==> 1
# Dai  ==> 1
# Luo  ==> 1
# Nakagawa  ==> 1
# Rule  ==> 1
# Discover  ==> 1
# WIDM  ==> 1
# Atlanta  ==> 1
# GA  ==> 1
# USA  ==> 1
# Petenes  ==> 1
# Inference  ==> 1
# Proc  ==> 1
# WebKDD  ==> 1
# KDD  ==> 1
# Workshop  ==> 1
# Premise  ==> 1
# Intelligent  ==> 1
# Washington  ==> 1
# DC  ==> 1
# 37  ==> 1
# Frigui  ==> 1
# Joshi  ==> 1
# Krishnapuram  ==> 1
# Access  ==> 1
# Logs  ==> 1
# Competitive  ==> 1
# Eighth  ==> 1
# Congress  ==> 1
# Hsinchu  ==> 1
# Taiwan  ==> 1
# Invited  ==> 1
# chapter  ==> 1
# Encyclopedia  ==> 1
# Warehousing  ==> 1
# Ed  ==> 1
# Pierrakos  ==> 1
# Paliouras  ==> 1
# Papatheodorou  ==> 1
# Spyropoulos  ==> 1
# tool  ==> 1
# survey  ==> 1
# modelling  ==> 1
# adapted  ==> 1
# interaction  ==> 1
# journal  ==> 1
# 13  ==> 1
# 311  ==> 1
# 372  ==> 1
# Restore  ==> 1
# Restoring  ==> 1
# Missing  ==> 1
# Side  ==> 1
# UBB  ==> 1
# Unexpected  ==> 1
# Behaviour  ==> 1
# Design  ==> 1
# P  ==> 1
# Owoc  ==> 1
# Pleszkun  ==> 1
# 2012  ==> 1
# WWW  ==> 1
# Log  ==> 1
# Files  ==> 1
# Retrieved  ==> 1
# https  ==> 1
# en  ==> 1
# wikipedia  ==> 1
# org  ==> 1
# w  ==> 1
# index  ==> 1
# php  ==> 1
# title  ==> 1
# Web_mining  ==> 1
# oldid  ==> 1
# 904363144  ==> 1
# Categories  ==> 1
# analyticsData  ==> 1
# miningWorld  ==> 1
# WebHidden  ==> 1
# Articles  ==> 1
# cleanupCleanup  ==> 1
# tagged  ==> 1
# field  ==> 1
# 2009Wikipedia  ==> 1
# 2009Articles  ==> 1
# expanded  ==> 1
# 2015All  ==> 1
# expandedArticles  ==> 1
# small  ==> 1
# boxesArticles  ==> 1
# menu  ==> 1
# Personal  ==> 1
# Not  ==> 1
# logged  ==> 1
# inTalkContributionsCreate  ==> 1
# accountLog  ==> 1
# Namespaces  ==> 1
# ArticleTalk  ==> 1
# Variants  ==> 1
# Views  ==> 1
# ReadEditView  ==> 1
# history  ==> 1
# pageContentsFeatured  ==> 1
# contentCurrent  ==> 1
# eventsRandom  ==> 1
# articleDonate  ==> 1
# WikipediaWikipedia  ==> 1
# store  ==> 1
# Interaction  ==> 1
# HelpAbout  ==> 1
# WikipediaCommunity  ==> 1
# portalRecent  ==> 1
# changesContact  ==> 1
# Tools  ==> 1
# What  ==> 1
# hereRelated  ==> 1
# changesUpload  ==> 1
# fileSpecial  ==> 1
# pagesPermanent  ==> 1
# linkPage  ==> 1
# informationWikidata  ==> 1
# itemCite  ==> 1
# Print  ==> 1
# export  ==> 1
# Create  ==> 1
# bookDownload  ==> 1
# PDFPrintable  ==> 1
# version  ==> 1
# Languages  ==> 1
# العربيةDeutschEspañolEuskaraفارسیFrançais한국어ह  ==> 1
# न  ==> 1
# द  ==> 1
# HrvatskiMagyar日本語PortuguêsРусскийSlovenčinaไทย  ==> 1
# Edit  ==> 1
# last  ==> 1
# edited  ==> 1
# 2019  ==> 1
# 17  ==> 1
# 30  ==> 1
# UTC  ==> 1
# Creative  ==> 1
# Commons  ==> 1
# Attribution  ==> 1
# ShareAlike  ==> 1
# License  ==> 1
# apply  ==> 1
# agree  ==> 1
# Terms  ==> 1
# Use  ==> 1
# Policy  ==> 1
# registered  ==> 1
# trademark  ==> 1
# Wikimedia  ==> 1
# Foundation  ==> 1
# Inc  ==> 1
# non  ==> 1
# profit  ==> 1
# policy  ==> 1
# About  ==> 1
# Disclaimers  ==> 1
# Contact  ==> 1
# Developers  ==> 1
# Cookie  ==> 1
# statement  ==> 1
# Mobile  ==> 1

# %%
#display the number of words and term frequency of each word present
#along with their corresponding stemmed words present
#after applying stemming to whole text
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
stem_words=[]
for word in words:
    stem_words.append(stemmer.stem(word))
fdist = nltk.FreqDist(stem_words)
for word, frequency in fdist.most_common():
    print('{}  ==>  {}  ==> {}'.format(word, frequency,stemmer.stem(word)))
# Out:
# web  ==>  125  ==> web
# mine  ==>  90  ==> mine
# data  ==>  59  ==> data
# structur  ==>  41  ==> structur
# usag  ==>  28  ==> usag
# use  ==>  24  ==> use
# inform  ==>  23  ==> inform
# the  ==>  21  ==> the
# content  ==>  19  ==> content
# document  ==>  19  ==> document
# pattern  ==>  18  ==> pattern
# page  ==>  18  ==> page
# applic  ==>  17  ==> applic
# edit  ==>  16  ==> edit
# user  ==>  15  ==> user
# site  ==>  14  ==> site
# person  ==>  14  ==> person
# link  ==>  12  ==> link
# 1  ==>  12  ==> 1
# thi  ==>  11  ==> thi
# log  ==>  11  ==> log
# base  ==>  11  ==> base
# techniqu  ==>  10  ==> techniqu
# server  ==>  10  ==> server
# gener  ==>  10  ==> gener
# view  ==>  10  ==> view
# custom  ==>  10  ==> custom
# 2  ==>  9  ==> 2
# need  ==>  9  ==> need
# wikipedia  ==>  8  ==> wikipedia
# articl  ==>  8  ==> articl
# text  ==>  8  ==> text
# algorithm  ==>  8  ==> algorithm
# featur  ==>  8  ==> featur
# technolog  ==>  8  ==> technolog
# analysi  ==>  8  ==> analysi
# knowledg  ==>  8  ==> knowledg
# issu  ==>  8  ==> issu
# privaci  ==>  8  ==> privaci
# intellig  ==>  8  ==> intellig
# wide  ==>  7  ==> wide
# hyperlink  ==>  7  ==> hyperlink
# type  ==>  7  ==> type
# refer  ==>  7  ==> refer
# word  ==>  7  ==> word
# graph  ==>  7  ==> graph
# find  ==>  7  ==> find
# discoveri  ==>  7  ==> discoveri
# tool  ==>  7  ==> tool
# compani  ==>  7  ==> compani
# individu  ==>  7  ==> individu
# june  ==>  6  ==> june
# discov  ==>  6  ==> discov
# world  ==>  6  ==> world
# make  ==>  6  ==> make
# organ  ==>  6  ==> organ
# differ  ==>  6  ==> differ
# provid  ==>  6  ==> provid
# 4  ==>  6  ==> 4
# 6  ==>  6  ==> 6
# 7  ==>  6  ==> 7
# categori  ==>  6  ==> categori
# semi  ==>  6  ==> semi
# extract  ==>  6  ==> extract
# might  ==>  6  ==> might
# obtain  ==>  6  ==> obtain
# B  ==>  6  ==> B
# 2005  ==>  6  ==> 2005
# mobash  ==>  6  ==> mobash
# R  ==>  6  ==> R
# vol  ==>  6  ==> vol
# navig  ==>  5  ==> navig
# search  ==>  5  ==> search
# learn  ==>  5  ==> learn
# categor  ==>  5  ==> categor
# also  ==>  5  ==> also
# databas  ==>  5  ==> databa
# relat  ==>  5  ==> relat
# includ  ==>  5  ==> includ
# associ  ==>  5  ==> associ
# rule  ==>  5  ==> rule
# cluster  ==>  5  ==> cluster
# system  ==>  5  ==> system
# result  ==>  5  ==> result
# node  ==>  5  ==> node
# research  ==>  5  ==> research
# code  ==>  5  ==> code
# springer  ==>  5  ==> springer
# 2000  ==>  5  ==> 2000
# nasraoui  ==>  5  ==> nasraoui
# 2006  ==>  5  ==> 2006
# pp  ==>  5  ==> pp
# M  ==>  5  ==> M
# 2003  ==>  5  ==> 2003
# cleanup  ==>  4  ==> cleanup
# No  ==>  4  ==> No
# It  ==>  4  ==> It
# util  ==>  4  ==> util
# unstructur  ==>  4  ==> unstructur
# websit  ==>  4  ==> websit
# relationship  ==>  4  ==> relationship
# access  ==>  4  ==> access
# 3  ==>  4  ==> 3
# languag  ==>  4  ==> languag
# chines  ==>  4  ==> chine
# hypertext  ==>  4  ==> hypertext
# term  ==>  4  ==> term
# better  ==>  4  ==> better
# captur  ==>  4  ==> captur
# brows  ==>  4  ==> brow
# kind  ==>  4  ==> kind
# commerc  ==>  4  ==> commerc
# A  ==>  4  ==> A
# combin  ==>  4  ==> combin
# one  ==>  4  ==> one
# appli  ==>  4  ==> appli
# concern  ==>  4  ==> concern
# two  ==>  4  ==> two
# develop  ==>  4  ==> develop
# particular  ==>  4  ==> particular
# trade  ==>  4  ==> trade
# identifi  ==>  4  ==> identifi
# specif  ==>  4  ==> specif
# model  ==>  4  ==> model
# ethic  ==>  4  ==> ethic
# de  ==>  4  ==> de
# attribut  ==>  4  ==> attribut
# retriev  ==>  4  ==> retriev
# p  ==>  4  ==> p
# proceed  ==>  4  ==> proceed
# 2004  ==>  4  ==> 2004
# 2007  ==>  4  ==> 2007
# citat  ==>  4  ==> citat
# daniel  ==>  4  ==> daniel
# artifici  ==>  4  ==> artifici
# J  ==>  4  ==> J
# requir  ==>  3  ==> requir
# standard  ==>  3  ==> standard
# reason  ==>  3  ==> reason
# help  ==>  3  ==> help
# improv  ==>  3  ==> improv
# messag  ==>  3  ==> messag
# As  ==>  3  ==> As
# sourc  ==>  3  ==> sourc
# technic  ==>  3  ==> technic
# tri  ==>  3  ==> tri
# level  ==>  3  ==> level
# schema  ==>  3  ==> schema
# purpos  ==>  3  ==> purpo
# integr  ==>  3  ==> integr
# introduc  ==>  3  ==> introduc
# 5  ==>  3  ==> 5
# interact  ==>  3  ==> interact
# represent  ==>  3  ==> repres
# method  ==>  3  ==> method
# machin  ==>  3  ==> machin
# statist  ==>  3  ==> statist
# manag  ==>  3  ==> manag
# behavior  ==>  3  ==> behavior
# classifi  ==>  3  ==> classifi
# consid  ==>  3  ==> consid
# collect  ==>  3  ==> collect
# time  ==>  3  ==> time
# event  ==>  3  ==> event
# defin  ==>  3  ==> defin
# thu  ==>  3  ==> thu
# work  ==>  3  ==> work
# semant  ==>  3  ==> semant
# commun  ==>  3  ==> commun
# benefit  ==>  3  ==> benefit
# they  ==>  3  ==> they
# increas  ==>  3  ==> increa
# profil  ==>  3  ==> profil
# creat  ==>  3  ==> creat
# addit  ==>  3  ==> addit
# these  ==>  3  ==> these
# analyz  ==>  3  ==> analyz
# without  ==>  3  ==> without
# anonym  ==>  3  ==> anonym
# group  ==>  3  ==> group
# import  ==>  3  ==> import
# releas  ==>  3  ==> relea
# legal  ==>  3  ==> legal
# infer  ==>  3  ==> infer
# tree  ==>  3  ==> tree
# html  ==>  3  ==> html
# repres  ==>  3  ==> repr
# number  ==>  3  ==> number
# point  ==>  3  ==> point
# lack  ==>  3  ==> lack
# evalu  ==>  3  ==> evalu
# taxonomi  ==>  3  ==> taxonomi
# G  ==>  3  ==> G
# isbn  ==>  3  ==> isbn
# intern  ==>  3  ==> intern
# confer  ==>  3  ==> confer
# septemb  ==>  3  ==> septemb
# 1999  ==>  3  ==> 1999
# workshop  ==>  3  ==> workshop
# In  ==>  3  ==> In
# acm  ==>  3  ==> acm
# cooley  ==>  3  ==> cooley
# journal  ==>  3  ==> journal
# I  ==>  3  ==> I
# hsien  ==>  3  ==> hsien
# ting  ==>  3  ==> ting
# chri  ==>  3  ==> chri
# kimbl  ==>  3  ==> kimbl
# kudenko  ==>  3  ==> kudenko
# clickstream  ==>  3  ==> clickstream
# O  ==>  3  ==> O
# C  ==>  3  ==> C
# fuzzi  ==>  3  ==> fuzzi
# encyclopedia  ==>  2  ==> encyclopedia
# jump  ==>  2  ==> jump
# may  ==>  2  ==> may
# pleas  ==>  2  ==> plea
# 2009  ==>  2  ==> 2009
# remov  ==>  2  ==> remov
# templat  ==>  2  ==> templat
# name  ==>  2  ==> name
# autom  ==>  2  ==> autom
# reveal  ==>  2  ==> reveal
# permit  ==>  2  ==> permit
# browser  ==>  2  ==> browser
# activ  ==>  2  ==> activ
# inner  ==>  2  ==> inner
# similar  ==>  2  ==> similar
# anoth  ==>  2  ==> anoth
# direct  ==>  2  ==> direct
# compar  ==>  2  ==> compar
# pro  ==>  2  ==> pro
# con  ==>  2  ==> con
# foreign  ==>  2  ==> foreign
# see  ==>  2  ==> see
# resourc  ==>  2  ==> resourc
# extern  ==>  2  ==> extern
# book  ==>  2  ==> book
# bibliograph  ==>  2  ==> bibliograph
# divid  ==>  2  ==> divid
# DB  ==>  2  ==> DB
# main  ==>  2  ==> main
# bag  ==>  2  ==> bag
# edg  ==>  2  ==> edg
# proprietari  ==>  2  ==> proprietari
# construct  ==>  2  ==> construct
# adapt  ==>  2  ==> adapt
# interest  ==>  2  ==> interest
# order  ==>  2  ==> order
# understand  ==>  2  ==> understand
# typic  ==>  2  ==> typic
# address  ==>  2  ==> address
# enabl  ==>  2  ==> enabl
# e  ==>  2  ==> e
# histori  ==>  2  ==> histori
# mani  ==>  2  ==> mani
# area  ==>  2  ==> area
# costa  ==>  2  ==> costa
# seco  ==>  2  ==> seco
# demonstr  ==>  2  ==> demonstr
# hyponymi  ==>  2  ==> hyponymi
# given  ==>  2  ==> given
# essenti  ==>  2  ==> essenti
# attract  ==>  2  ==> attract
# govern  ==>  2  ==> govern
# agenc  ==>  2  ==> agenc
# higher  ==>  2  ==> higher
# threat  ==>  2  ==> threat
# capabl  ==>  2  ==> capabl
# retain  ==>  2  ==> retain
# profit  ==>  2  ==> profit
# target  ==>  2  ==> target
# offer  ==>  2  ==> offer
# more  ==>  2  ==> more
# process  ==>  2  ==> process
# tradit  ==>  2  ==> tradit
# valid  ==>  2  ==> valid
# there  ==>  2  ==> there
# show  ==>  2  ==> show
# way  ==>  2  ==> way
# interpret  ==>  2  ==> interpret
# involv  ==>  2  ==> involv
# made  ==>  2  ==> made
# judg  ==>  2  ==> judg
# characterist  ==>  2  ==> characterist
# merit  ==>  2  ==> merit
# trend  ==>  2  ==> trend
# controversi  ==>  2  ==> controversi
# like  ==>  2  ==> like
# race  ==>  2  ==> race
# religion  ==>  2  ==> religion
# sexual  ==>  2  ==> sexual
# orient  ==>  2  ==> orient
# servic  ==>  2  ==> servic
# section  ==>  2  ==> section
# connect  ==>  2  ==> connect
# compon  ==>  2  ==> compon
# tag  ==>  2  ==> tag
# degre  ==>  2  ==> degr
# googl  ==>  2  ==> googl
# rank  ==>  2  ==> rank
# expand  ==>  2  ==> expand
# index  ==>  2  ==> index
# internet  ==>  2  ==> internet
# agent  ==>  2  ==> agent
# avail  ==>  2  ==> avail
# approach  ==>  2  ==> approach
# autonom  ==>  2  ==> autonom
# 8  ==>  2  ==> 8
# 9  ==>  2  ==> 9
# singl  ==>  2  ==> singl
# queri  ==>  2  ==> queri
# transform  ==>  2  ==> transform
# vector  ==>  2  ==> vector
# space  ==>  2  ==> space
# frequenc  ==>  2  ==> frequenc
# By  ==>  2  ==> By
# usual  ==>  2  ==> usual
# precis  ==>  2  ==> preci
# common  ==>  2  ==> common
# scrape  ==>  2  ==> scrape
# galitski  ==>  2  ==> galitski
# dobrocsi  ==>  2  ==> dobrocsi
# la  ==>  2  ==> la
# rosa  ==>  2  ==> rosa
# JL  ==>  2  ==> JL
# kuznetsov  ==>  2  ==> kuznetsov
# SO  ==>  2  ==> SO
# syntact  ==>  2  ==> syntact
# pars  ==>  2  ==> par
# icc  ==>  2  ==> icc
# 2011  ==>  2  ==> 2011
# 8323  ==>  2  ==> 8323
# weichbroth  ==>  2  ==> weichbroth
# berlin  ==>  2  ==> berlin
# 15  ==>  2  ==> 15
# 978  ==>  2  ==> 978
# idea  ==>  2  ==> idea
# pdf  ==>  2  ==> pdf
# F  ==>  2  ==> F
# preserv  ==>  2  ==> preserv
# wang  ==>  2  ==> wang
# juli  ==>  2  ==> juli
# survey  ==>  2  ==> survey
# explor  ==>  2  ==> explor
# T  ==>  2  ==> T
# press  ==>  2  ==> press
# bing  ==>  2  ==> bing
# liu  ==>  2  ==> liu
# revis  ==>  2  ==> revi
# paper  ==>  2  ==> paper
# th  ==>  2  ==> th
# olfa  ==>  2  ==> olfa
# bamshad  ==>  2  ==> bamshad
# brij  ==>  2  ==> brij
# masand  ==>  2  ==> masand
# ed  ==>  2  ==> ed
# lectur  ==>  2  ==> lectur
# note  ==>  2  ==> note
# srivastava  ==>  2  ==> srivastava
# H  ==>  2  ==> H
# 2001  ==>  2  ==> 2001
# effect  ==>  2  ==> effect
# august  ==>  2  ==> august
# D  ==>  2  ==> D
# restor  ==>  2  ==> restor
# 2009all  ==>  2  ==> 2009all
# polici  ==>  2  ==> polici
# from  ==>  1  ==> from
# free  ==>  1  ==> free
# meet  ==>  1  ==> meet
# qualiti  ==>  1  ==> qualiti
# specifi  ==>  1  ==> specifi
# propos  ==>  1  ==> propo
# gather  ==>  1  ==> gather
# apparatus  ==>  1  ==> apparatu
# extric  ==>  1  ==> extric
# web2  ==>  1  ==> web2
# report  ==>  1  ==> report
# get  ==>  1  ==> get
# goal  ==>  1  ==> goal
# summari  ==>  1  ==> summari
# mainli  ==>  1  ==> mainli
# focus  ==>  1  ==> focu
# inter  ==>  1  ==> inter
# topolog  ==>  1  ==> topolog
# would  ==>  1  ==> would
# good  ==>  1  ==> good
# possibl  ==>  1  ==> possibl
# scheme  ==>  1  ==> scheme
# facilit  ==>  1  ==> facilit
# three  ==>  1  ==> three
# object  ==>  1  ==> object
# comparison  ==>  1  ==> comparison
# IR  ==>  1  ==> IR
# n  ==>  1  ==> n
# gram  ==>  1  ==> gram
# phrase  ==>  1  ==> phrase
# concept  ==>  1  ==> concept
# ontolog  ==>  1  ==> ontolog
# labe  ==>  1  ==> labe
# tabl  ==>  1  ==> tabl
# nlp  ==>  1  ==> nlp
# frequent  ==>  1  ==> frequent
# sub  ==>  1  ==> sub
# serv  ==>  1  ==> serv
# ident  ==>  1  ==> ident
# origin  ==>  1  ==> origin
# along  ==>  1  ==> along
# depend  ==>  1  ==> depend
# IP  ==>  1  ==> IP
# commerci  ==>  1  ==> commerci
# signific  ==>  1  ==> signif
# built  ==>  1  ==> built
# top  ==>  1  ==> top
# littl  ==>  1  ==> littl
# effort  ==>  1  ==> effort
# key  ==>  1  ==> key
# abil  ==>  1  ==> abil
# track  ==>  1  ==> track
# variou  ==>  1  ==> variou
# busi  ==>  1  ==> busi
# new  ==>  1  ==> new
# turn  ==>  1  ==> turn
# special  ==>  1  ==> special
# end  ==>  1  ==> end
# studi  ==>  1  ==> studi
# constraint  ==>  1  ==> constraint
# softwar  ==>  1  ==> softwar
# advantag  ==>  1  ==> advantag
# corpor  ==>  1  ==> corpor
# market  ==>  1  ==> market
# eventu  ==>  1  ==> eventu
# volum  ==>  1  ==> volum
# fight  ==>  1  ==> fight
# terror  ==>  1  ==> terror
# predict  ==>  1  ==> predict
# societi  ==>  1  ==> societi
# crimin  ==>  1  ==> crimin
# establish  ==>  1  ==> establish
# react  ==>  1  ==> react
# faster  ==>  1  ==> faster
# save  ==>  1  ==> save
# product  ==>  1  ==> product
# cost  ==>  1  ==> cost
# acquir  ==>  1  ==> acquir
# insight  ==>  1  ==> insight
# price  ==>  1  ==> price
# even  ==>  1  ==> even
# default  ==>  1  ==> default
# competitor  ==>  1  ==> competitor
# promot  ==>  1  ==> promot
# reduc  ==>  1  ==> reduc
# risk  ==>  1  ==> risk
# lose  ==>  1  ==> lose
# particularli  ==>  1  ==> particularli
# outlin  ==>  1  ==> outlin
# framework  ==>  1  ==> framework
# probabilist  ==>  1  ==> probabilist
# latent  ==>  1  ==> latent
# relev  ==>  1  ==> relev
# collabor  ==>  1  ==> collabor
# recommend  ==>  1  ==> recommend
# problem  ==>  1  ==> problem
# bias  ==>  1  ==> bia
# question  ==>  1  ==> question
# regard  ==>  1  ==> regard
# sinc  ==>  1  ==> sinc
# subject  ==>  1  ==> subject
# degrad  ==>  1  ==> degrad
# element  ==>  1  ==> element
# uniqu  ==>  1  ==> uniqu
# phase  ==>  1  ==> phase
# natur  ==>  1  ==> natur
# caus  ==>  1  ==> cau
# critic  ==>  1  ==> critic
# invas  ==>  1  ==> inva
# lost  ==>  1  ==> lost
# dissemin  ==>  1  ==> dissemin
# especi  ==>  1  ==> especi
# occur  ==>  1  ==> occur
# consent  ==>  1  ==> consent
# form  ==>  1  ==> form
# mous  ==>  1  ==> mou
# click  ==>  1  ==> click
# De  ==>  1  ==> De
# tendenc  ==>  1  ==> tendenc
# treat  ==>  1  ==> treat
# peopl  ==>  1  ==> peopl
# basi  ==>  1  ==> basi
# instead  ==>  1  ==> instead
# total  ==>  1  ==> total
# violat  ==>  1  ==> violat
# grow  ==>  1  ==> grow
# sell  ==>  1  ==> sell
# commod  ==>  1  ==> commod
# encourag  ==>  1  ==> encourag
# owner  ==>  1  ==> owner
# amount  ==>  1  ==> amount
# likeli  ==>  1  ==> like
# invad  ==>  1  ==> invad
# buy  ==>  1  ==> buy
# oblig  ==>  1  ==> oblig
# author  ==>  1  ==> author
# respons  ==>  1  ==> respon
# inaccuraci  ==>  1  ==> inaccuraci
# seriou  ==>  1  ==> seriou
# lawsuit  ==>  1  ==> lawsuit
# law  ==>  1  ==> law
# prevent  ==>  1  ==> prevent
# some  ==>  1  ==> some
# sex  ==>  1  ==> sex
# practic  ==>  1  ==> practic
# anti  ==>  1  ==> anti
# discrimin  ==>  1  ==> discrimin
# legisl  ==>  1  ==> legisl
# hard  ==>  1  ==> hard
# strong  ==>  1  ==> strong
# could  ==>  1  ==> could
# denial  ==>  1  ==> denial
# privileg  ==>  1  ==> privileg
# right  ==>  1  ==> right
# situat  ==>  1  ==> situat
# avoid  ==>  1  ==> avoid
# high  ==>  1  ==> high
# maintain  ==>  1  ==> maintain
# cannot  ==>  1  ==> cannot
# trace  ==>  1  ==> trace
# back  ==>  1  ==> back
# look  ==>  1  ==> look
# pose  ==>  1  ==> pose
# howev  ==>  1  ==> howev
# separ  ==>  1  ==> separ
# unscrupul  ==>  1  ==> unscrupul
# expans  ==>  1  ==> expan
# you  ==>  1  ==> you
# ad  ==>  1  ==> ad
# 2015  ==>  1  ==> 2015
# theori  ==>  1  ==> theori
# accord  ==>  1  ==> accord
# locat  ==>  1  ==> locat
# describ  ==>  1  ==> describ
# xml  ==>  1  ==> xml
# terminolog  ==>  1  ==> terminolog
# pagerank  ==>  1  ==> pagerank
# founder  ==>  1  ==> founder
# larri  ==>  1  ==> larri
# decid  ==>  1  ==> decid
# heterogen  ==>  1  ==> heterogen
# much  ==>  1  ==> much
# ever  ==>  1  ==> ever
# lyco  ==>  1  ==> lyco
# alta  ==>  1  ==> alta
# vista  ==>  1  ==> vista
# webcrawl  ==>  1  ==> webcrawl
# aliweb  ==>  1  ==> aliweb
# metacrawl  ==>  1  ==> metacrawl
# other  ==>  1  ==> other
# comfort  ==>  1  ==> comfort
# filter  ==>  1  ==> filter
# factor  ==>  1  ==> factor
# prompt  ==>  1  ==> prompt
# well  ==>  1  ==> well
# extend  ==>  1  ==> extend
# sophist  ==>  1  ==> sophist
# AI  ==>  1  ==> AI
# act  ==>  1  ==> act
# behalf  ==>  1  ==> behalf
# differenti  ==>  1  ==> differenti
# summar  ==>  1  ==> summar
# done  ==>  1  ==> done
# isol  ==>  1  ==> isol
# take  ==>  1  ==> take
# found  ==>  1  ==> found
# train  ==>  1  ==> train
# corpu  ==>  1  ==> corpu
# for  ==>  1  ==> for
# insid  ==>  1  ==> insid
# alway  ==>  1  ==> alway
# becom  ==>  1  ==> becom
# sever  ==>  1  ==> sever
# constitut  ==>  1  ==> constitut
# whole  ==>  1  ==> whole
# realiz  ==>  1  ==> realiz
# To  ==>  1  ==> To
# resolv  ==>  1  ==> resolv
# tf  ==>  1  ==> tf
# idf  ==>  1  ==> idf
# invers  ==>  1  ==> inver
# multi  ==>  1  ==> multi
# scan  ==>  1  ==> scan
# implement  ==>  1  ==> implement
# select  ==>  1  ==> select
# under  ==>  1  ==> under
# condit  ==>  1  ==> condit
# rare  ==>  1  ==> rare
# affect  ==>  1  ==> affect
# subset  ==>  1  ==> subset
# function  ==>  1  ==> function
# set  ==>  1  ==> set
# gain  ==>  1  ==> gain
# cross  ==>  1  ==> cross
# entropi  ==>  1  ==> entropi
# mutual  ==>  1  ==> mutual
# odd  ==>  1  ==> odd
# ratio  ==>  1  ==> ratio
# classif  ==>  1  ==> classif
# accuraci  ==>  1  ==> accuraci
# recal  ==>  1  ==> recal
# score  ==>  1  ==> score
# pipelin  ==>  1  ==> pipelin
# portal  ==>  1  ==> portal
# confirm  ==>  1  ==> confirm
# verif  ==>  1  ==> verif
# build  ==>  1  ==> build
# opinion  ==>  1  ==> opinion
# 10  ==>  1  ==> 10
# complic  ==>  1  ==> complic
# english  ==>  1  ==> english
# GB  ==>  1  ==> GB
# big5  ==>  1  ==> big5
# HZ  ==>  1  ==> HZ
# befor  ==>  1  ==> befor
# analyt  ==>  1  ==> analyt
# et  ==>  1  ==> et
# al  ==>  1  ==> al
# ngu  ==>  1  ==> ngu
# ann  ==>  1  ==> ann
# kitsuregawa  ==>  1  ==> kitsuregawa
# masaru  ==>  1  ==> masaru
# chung  ==>  1  ==> chung
# jen  ==>  1  ==> jen
# yao  ==>  1  ==> yao
# neuhold  ==>  1  ==> neuhold
# erich  ==>  1  ==> erich
# sheng  ==>  1  ==> sheng
# quan  ==>  1  ==> quan
# engin  ==>  1  ==> engin
# wise  ==>  1  ==> wise
# 9783540300175  ==>  1  ==> 9783540300175
# bauknecht  ==>  1  ==> bauknecht
# kurt  ==>  1  ==> kurt
# madria  ==>  1  ==> madria
# sanjay  ==>  1  ==> sanjay
# pernul  ==>  1  ==> pernul
# gunther  ==>  1  ==> gunther
# electron  ==>  1  ==> electron
# first  ==>  1  ==> first
# EC  ==>  1  ==> EC
# london  ==>  1  ==> london
# UK  ==>  1  ==> UK
# 165  ==>  1  ==> 165
# 3540679813  ==>  1  ==> 3540679813
# scime  ==>  1  ==> scime
# anthoni  ==>  1  ==> anthoni
# hershey  ==>  1  ==> hershey
# PA  ==>  1  ==> PA
# publish  ==>  1  ==> publish
# 282  ==>  1  ==> 282
# 1591404149  ==>  1  ==> 1591404149
# b  ==>  1  ==> b
# c  ==>  1  ==> c
# lita  ==>  1  ==> lita
# van  ==>  1  ==> van
# wel  ==>  1  ==> wel
# lambèr  ==>  1  ==> lambèr
# royakk  ==>  1  ==> royakk
# kirsten  ==>  1  ==> kirsten
# wahlstrom  ==>  1  ==> wahlstrom
# john  ==>  1  ==> john
# roddick  ==>  1  ==> roddick
# vladimir  ==>  1  ==> vladimir
# estivil  ==>  1  ==> estivil
# castro  ==>  1  ==> castro
# denis  ==>  1  ==> deni
# vri  ==>  1  ==> vri
# yan  ==>  1  ==> yan
# kosala  ==>  1  ==> kosala
# raymond  ==>  1  ==> raymond
# hendrik  ==>  1  ==> hendrik
# blockeel  ==>  1  ==> blockeel
# sigkdd  ==>  1  ==> sigkdd
# arxiv  ==>  1  ==> arxiv
# cs  ==>  1  ==> cs
# LG  ==>  1  ==> LG
# 0011033  ==>  1  ==> 0011033
# list  ==>  1  ==> list
# remain  ==>  1  ==> remain
# unclear  ==>  1  ==> unclear
# insuffici  ==>  1  ==> insuffici
# inlin  ==>  1  ==> inlin
# futur  ==>  1  ==> futur
# zdravko  ==>  1  ==> zdravko
# markov  ==>  1  ==> markov
# laros  ==>  1  ==> laro
# uncov  ==>  1  ==> uncov
# wiley  ==>  1  ==> wiley
# jesu  ==>  1  ==> jesu
# mena  ==>  1  ==> mena
# your  ==>  1  ==> your
# digit  ==>  1  ==> digit
# soumen  ==>  1  ==> soumen
# chakrabarti  ==>  1  ==> chakrabarti
# morgan  ==>  1  ==> morgan
# kaufmann  ==>  1  ==> kaufmann
# 2002  ==>  1  ==> 2002
# advanc  ==>  1  ==> advanc
# osmar  ==>  1  ==> osmar
# zaian  ==>  1  ==> zaian
# myra  ==>  1  ==> myra
# spiliopoul  ==>  1  ==> spiliopoul
# philip  ==>  1  ==> philip
# Yu  ==>  1  ==> Yu
# lnai  ==>  1  ==> lnai
# 4198  ==>  1  ==> 4198
# mike  ==>  1  ==> mike
# thelwal  ==>  1  ==> thelwal
# An  ==>  1  ==> An
# scienc  ==>  1  ==> scienc
# academ  ==>  1  ==> academ
# baraglia  ==>  1  ==> baraglia
# silvestri  ==>  1  ==> silvestri
# dynam  ==>  1  ==> dynam
# intervent  ==>  1  ==> interv
# 50  ==>  1  ==> 50
# 63  ==>  1  ==> 63
# 67  ==>  1  ==> 67
# srivastav  ==>  1  ==> srivastav
# 1997  ==>  1  ==> 1997
# 9th  ==>  1  ==> 9th
# ieee  ==>  1  ==> ieee
# prepar  ==>  1  ==> prepar
# 32  ==>  1  ==> 32
# RP  ==>  1  ==> RP
# N  ==>  1  ==> N
# On  ==>  1  ==> On
# reformul  ==>  1  ==> reformul
# 11th  ==>  1  ==> 11th
# ibero  ==>  1  ==> ibero
# american  ==>  1  ==> american
# 2008  ==>  1  ==> 2008
# octob  ==>  1  ==> octob
# kohavi  ==>  1  ==> kohavi
# mason  ==>  1  ==> mason
# L  ==>  1  ==> L
# zheng  ==>  1  ==> zheng
# Z  ==>  1  ==> Z
# lesson  ==>  1  ==> lesson
# challeng  ==>  1  ==> challeng
# retail  ==>  1  ==> retail
# E  ==>  1  ==> E
# 57  ==>  1  ==> 57
# 83  ==>  1  ==> 83
# 113  ==>  1  ==> 113
# lillian  ==>  1  ==> lillian
# clark  ==>  1  ==> clark
# peter  ==>  1  ==> peter
# wright  ==>  1  ==> wright
# ethnograph  ==>  1  ==> ethnograph
# strategi  ==>  1  ==> strategi
# 11  ==>  1  ==> 11
# januari  ==>  1  ==> januari
# eirinaki  ==>  1  ==> eirinaki
# vazirgianni  ==>  1  ==> vazirgianni
# transact  ==>  1  ==> transact
# februari  ==>  1  ==> februari
# automat  ==>  1  ==> automat
# 43  ==>  1  ==> 43
# 142  ==>  1  ==> 142
# 151  ==>  1  ==> 151
# dai  ==>  1  ==> dai
# luo  ==>  1  ==> luo
# nakagawa  ==>  1  ==> nakagawa
# widm  ==>  1  ==> widm
# atlanta  ==>  1  ==> atlanta
# GA  ==>  1  ==> GA
# usa  ==>  1  ==> usa
# peten  ==>  1  ==> peten
# proc  ==>  1  ==> proc
# webkdd  ==>  1  ==> webkdd
# kdd  ==>  1  ==> kdd
# premis  ==>  1  ==> premi
# washington  ==>  1  ==> washington
# DC  ==>  1  ==> DC
# 37  ==>  1  ==> 37
# frigui  ==>  1  ==> frigui
# joshi  ==>  1  ==> joshi
# krishnapuram  ==>  1  ==> krishnapuram
# competit  ==>  1  ==> competit
# eighth  ==>  1  ==> eighth
# congress  ==>  1  ==> congress
# hsinchu  ==>  1  ==> hsinchu
# taiwan  ==>  1  ==> taiwan
# invit  ==>  1  ==> invit
# chapter  ==>  1  ==> chapter
# wareh  ==>  1  ==> wareh
# Ed  ==>  1  ==> Ed
# pierrako  ==>  1  ==> pierrako
# palioura  ==>  1  ==> palioura
# papatheodor  ==>  1  ==> papatheodor
# spyropoulo  ==>  1  ==> spyropoulo
# 13  ==>  1  ==> 13
# 311  ==>  1  ==> 311
# 372  ==>  1  ==> 372
# miss  ==>  1  ==> miss
# side  ==>  1  ==> side
# ubb  ==>  1  ==> ubb
# unexpect  ==>  1  ==> unexpect
# behaviour  ==>  1  ==> behaviour
# design  ==>  1  ==> design
# P  ==>  1  ==> P
# owoc  ==>  1  ==> owoc
# pleszkun  ==>  1  ==> pleszkun
# 2012  ==>  1  ==> 2012
# www  ==>  1  ==> www
# file  ==>  1  ==> file
# http  ==>  1  ==> http
# en  ==>  1  ==> en
# org  ==>  1  ==> org
# w  ==>  1  ==> w
# php  ==>  1  ==> php
# titl  ==>  1  ==> titl
# web_min  ==>  1  ==> web_min
# oldid  ==>  1  ==> oldid
# 904363144  ==>  1  ==> 904363144
# analyticsdata  ==>  1  ==> analyticsdata
# miningworld  ==>  1  ==> miningworld
# webhidden  ==>  1  ==> webhidden
# cleanupcleanup  ==>  1  ==> cleanupcleanup
# field  ==>  1  ==> field
# 2009wikipedia  ==>  1  ==> 2009wikipedia
# 2009articl  ==>  1  ==> 2009articl
# 2015all  ==>  1  ==> 2015all
# expandedarticl  ==>  1  ==> expandedarticl
# small  ==>  1  ==> small
# boxesarticl  ==>  1  ==> boxesarticl
# menu  ==>  1  ==> menu
# not  ==>  1  ==> not
# intalkcontributionscr  ==>  1  ==> intalkcontributionscr
# accountlog  ==>  1  ==> accountlog
# namespac  ==>  1  ==> namespac
# articletalk  ==>  1  ==> articletalk
# variant  ==>  1  ==> variant
# readeditview  ==>  1  ==> readeditview
# pagecontentsfeatur  ==>  1  ==> pagecontentsfeatur
# contentcurr  ==>  1  ==> contentcurr
# eventsrandom  ==>  1  ==> eventsrandom
# articledon  ==>  1  ==> articledon
# wikipediawikipedia  ==>  1  ==> wikipediawikipedia
# store  ==>  1  ==> store
# helpabout  ==>  1  ==> helpabout
# wikipediacommun  ==>  1  ==> wikipediacommun
# portalrec  ==>  1  ==> portalrec
# changescontact  ==>  1  ==> changescontact
# what  ==>  1  ==> what
# hererel  ==>  1  ==> hererel
# changesupload  ==>  1  ==> changesupload
# filespeci  ==>  1  ==> filespeci
# pagesperman  ==>  1  ==> pagesperman
# linkpag  ==>  1  ==> linkpag
# informationwikidata  ==>  1  ==> informationwikidata
# itemcit  ==>  1  ==> itemcit
# print  ==>  1  ==> print
# export  ==>  1  ==> export
# bookdownload  ==>  1  ==> bookdownload
# pdfprintabl  ==>  1  ==> pdfprintabl
# version  ==>  1  ==> version
# العربيةdeutschespañoleuskaraفارسیfrançais한국어ह  ==>  1  ==> العربيةdeutschespañoleuskaraفارسیfrançais한국어ह
# न  ==>  1  ==> न
# द  ==>  1  ==> द
# hrvatskimagyar日本語portuguêsрусскийslovenčinaไทย  ==>  1  ==> hrvatskimagyar日本語portuguêsрусскийslovenčinaไทย
# last  ==>  1  ==> last
# 2019  ==>  1  ==> 2019
# 17  ==>  1  ==> 17
# 30  ==>  1  ==> 30
# utc  ==>  1  ==> utc
# creativ  ==>  1  ==> creativ
# sharealik  ==>  1  ==> sharealik
# licens  ==>  1  ==> licen
# agre  ==>  1  ==> agr
# regist  ==>  1  ==> regist
# trademark  ==>  1  ==> trademark
# wikimedia  ==>  1  ==> wikimedia
# foundat  ==>  1  ==> foundat
# inc  ==>  1  ==> inc
# non  ==>  1  ==> non
# about  ==>  1  ==> about
# disclaim  ==>  1  ==> disclaim
# contact  ==>  1  ==> contact
# cooki  ==>  1  ==> cooki
# statement  ==>  1  ==> statement
# mobil  ==>  1  ==> mobil

# %%
#Adding new word to nltk stopword list
newStopWords = ['web','mine','data']
stopwords.extend(newStopWords)
#now again applying stopword removal to remove new word
words = [word for word in stem_words if word not in stopwords]
fdist = nltk.FreqDist(words)
for word, frequency in fdist.most_common():
    print('{}  ==> {}'.format(word, frequency))
# Out:
# structur  ==> 41
# usag  ==> 28
# use  ==> 24
# inform  ==> 23
# content  ==> 19
# document  ==> 19
# pattern  ==> 18
# page  ==> 18
# applic  ==> 17
# edit  ==> 16
# user  ==> 15
# site  ==> 14
# person  ==> 14
# link  ==> 12
# 1  ==> 12
# thi  ==> 11
# log  ==> 11
# base  ==> 11
# techniqu  ==> 10
# server  ==> 10
# gener  ==> 10
# view  ==> 10
# custom  ==> 10
# 2  ==> 9
# need  ==> 9
# wikipedia  ==> 8
# articl  ==> 8
# text  ==> 8
# algorithm  ==> 8
# featur  ==> 8
# technolog  ==> 8
# analysi  ==> 8
# knowledg  ==> 8
# issu  ==> 8
# privaci  ==> 8
# intellig  ==> 8
# wide  ==> 7
# hyperlink  ==> 7
# type  ==> 7
# refer  ==> 7
# word  ==> 7
# graph  ==> 7
# find  ==> 7
# discoveri  ==> 7
# tool  ==> 7
# compani  ==> 7
# individu  ==> 7
# june  ==> 6
# discov  ==> 6
# world  ==> 6
# make  ==> 6
# organ  ==> 6
# differ  ==> 6
# provid  ==> 6
# 4  ==> 6
# 6  ==> 6
# 7  ==> 6
# categori  ==> 6
# semi  ==> 6
# extract  ==> 6
# might  ==> 6
# obtain  ==> 6
# B  ==> 6
# 2005  ==> 6
# mobash  ==> 6
# R  ==> 6
# vol  ==> 6
# navig  ==> 5
# search  ==> 5
# learn  ==> 5
# categor  ==> 5
# also  ==> 5
# databas  ==> 5
# relat  ==> 5
# includ  ==> 5
# associ  ==> 5
# rule  ==> 5
# cluster  ==> 5
# system  ==> 5
# result  ==> 5
# node  ==> 5
# research  ==> 5
# code  ==> 5
# springer  ==> 5
# 2000  ==> 5
# nasraoui  ==> 5
# 2006  ==> 5
# pp  ==> 5
# M  ==> 5
# 2003  ==> 5
# cleanup  ==> 4
# No  ==> 4
# It  ==> 4
# util  ==> 4
# unstructur  ==> 4
# websit  ==> 4
# relationship  ==> 4
# access  ==> 4
# 3  ==> 4
# languag  ==> 4
# chines  ==> 4
# hypertext  ==> 4
# term  ==> 4
# better  ==> 4
# captur  ==> 4
# brows  ==> 4
# kind  ==> 4
# commerc  ==> 4
# A  ==> 4
# combin  ==> 4
# one  ==> 4
# appli  ==> 4
# concern  ==> 4
# two  ==> 4
# develop  ==> 4
# particular  ==> 4
# trade  ==> 4
# identifi  ==> 4
# specif  ==> 4
# model  ==> 4
# ethic  ==> 4
# de  ==> 4
# attribut  ==> 4
# retriev  ==> 4
# p  ==> 4
# proceed  ==> 4
# 2004  ==> 4
# 2007  ==> 4
# citat  ==> 4
# daniel  ==> 4
# artifici  ==> 4
# J  ==> 4
# requir  ==> 3
# standard  ==> 3
# reason  ==> 3
# help  ==> 3
# improv  ==> 3
# messag  ==> 3
# As  ==> 3
# sourc  ==> 3
# technic  ==> 3
# tri  ==> 3
# level  ==> 3
# schema  ==> 3
# purpos  ==> 3
# integr  ==> 3
# introduc  ==> 3
# 5  ==> 3
# interact  ==> 3
# represent  ==> 3
# method  ==> 3
# machin  ==> 3
# statist  ==> 3
# manag  ==> 3
# behavior  ==> 3
# classifi  ==> 3
# consid  ==> 3
# collect  ==> 3
# time  ==> 3
# event  ==> 3
# defin  ==> 3
# thu  ==> 3
# work  ==> 3
# semant  ==> 3
# commun  ==> 3
# benefit  ==> 3
# increas  ==> 3
# profil  ==> 3
# creat  ==> 3
# addit  ==> 3
# analyz  ==> 3
# without  ==> 3
# anonym  ==> 3
# group  ==> 3
# import  ==> 3
# releas  ==> 3
# legal  ==> 3
# infer  ==> 3
# tree  ==> 3
# html  ==> 3
# repres  ==> 3
# number  ==> 3
# point  ==> 3
# lack  ==> 3
# evalu  ==> 3
# taxonomi  ==> 3
# G  ==> 3
# isbn  ==> 3
# intern  ==> 3
# confer  ==> 3
# septemb  ==> 3
# 1999  ==> 3
# workshop  ==> 3
# In  ==> 3
# acm  ==> 3
# cooley  ==> 3
# journal  ==> 3
# I  ==> 3
# hsien  ==> 3
# ting  ==> 3
# chri  ==> 3
# kimbl  ==> 3
# kudenko  ==> 3
# clickstream  ==> 3
# O  ==> 3
# C  ==> 3
# fuzzi  ==> 3
# encyclopedia  ==> 2
# jump  ==> 2
# may  ==> 2
# pleas  ==> 2
# 2009  ==> 2
# remov  ==> 2
# templat  ==> 2
# name  ==> 2
# autom  ==> 2
# reveal  ==> 2
# permit  ==> 2
# browser  ==> 2
# activ  ==> 2
# inner  ==> 2
# similar  ==> 2
# anoth  ==> 2
# direct  ==> 2
# compar  ==> 2
# pro  ==> 2
# con  ==> 2
# foreign  ==> 2
# see  ==> 2
# resourc  ==> 2
# extern  ==> 2
# book  ==> 2
# bibliograph  ==> 2
# divid  ==> 2
# DB  ==> 2
# main  ==> 2
# bag  ==> 2
# edg  ==> 2
# proprietari  ==> 2
# construct  ==> 2
# adapt  ==> 2
# interest  ==> 2
# order  ==> 2
# understand  ==> 2
# typic  ==> 2
# address  ==> 2
# enabl  ==> 2
# e  ==> 2
# histori  ==> 2
# mani  ==> 2
# area  ==> 2
# costa  ==> 2
# seco  ==> 2
# demonstr  ==> 2
# hyponymi  ==> 2
# given  ==> 2
# essenti  ==> 2
# attract  ==> 2
# govern  ==> 2
# agenc  ==> 2
# higher  ==> 2
# threat  ==> 2
# capabl  ==> 2
# retain  ==> 2
# profit  ==> 2
# target  ==> 2
# offer  ==> 2
# process  ==> 2
# tradit  ==> 2
# valid  ==> 2
# show  ==> 2
# way  ==> 2
# interpret  ==> 2
# involv  ==> 2
# made  ==> 2
# judg  ==> 2
# characterist  ==> 2
# merit  ==> 2
# trend  ==> 2
# controversi  ==> 2
# like  ==> 2
# race  ==> 2
# religion  ==> 2
# sexual  ==> 2
# orient  ==> 2
# servic  ==> 2
# section  ==> 2
# connect  ==> 2
# compon  ==> 2
# tag  ==> 2
# degre  ==> 2
# googl  ==> 2
# rank  ==> 2
# expand  ==> 2
# index  ==> 2
# internet  ==> 2
# agent  ==> 2
# avail  ==> 2
# approach  ==> 2
# autonom  ==> 2
# 8  ==> 2
# 9  ==> 2
# singl  ==> 2
# queri  ==> 2
# transform  ==> 2
# vector  ==> 2
# space  ==> 2
# frequenc  ==> 2
# By  ==> 2
# usual  ==> 2
# precis  ==> 2
# common  ==> 2
# scrape  ==> 2
# galitski  ==> 2
# dobrocsi  ==> 2
# la  ==> 2
# rosa  ==> 2
# JL  ==> 2
# kuznetsov  ==> 2
# SO  ==> 2
# syntact  ==> 2
# pars  ==> 2
# icc  ==> 2
# 2011  ==> 2
# 8323  ==> 2
# weichbroth  ==> 2
# berlin  ==> 2
# 15  ==> 2
# 978  ==> 2
# idea  ==> 2
# pdf  ==> 2
# F  ==> 2
# preserv  ==> 2
# wang  ==> 2
# juli  ==> 2
# survey  ==> 2
# explor  ==> 2
# T  ==> 2
# press  ==> 2
# bing  ==> 2
# liu  ==> 2
# revis  ==> 2
# paper  ==> 2
# th  ==> 2
# olfa  ==> 2
# bamshad  ==> 2
# brij  ==> 2
# masand  ==> 2
# ed  ==> 2
# lectur  ==> 2
# note  ==> 2
# srivastava  ==> 2
# H  ==> 2
# 2001  ==> 2
# effect  ==> 2
# august  ==> 2
# D  ==> 2
# restor  ==> 2
# 2009all  ==> 2
# polici  ==> 2
# free  ==> 1
# meet  ==> 1
# qualiti  ==> 1
# specifi  ==> 1
# propos  ==> 1
# gather  ==> 1
# apparatus  ==> 1
# extric  ==> 1
# web2  ==> 1
# report  ==> 1
# get  ==> 1
# goal  ==> 1
# summari  ==> 1
# mainli  ==> 1
# focus  ==> 1
# inter  ==> 1
# topolog  ==> 1
# would  ==> 1
# good  ==> 1
# possibl  ==> 1
# scheme  ==> 1
# facilit  ==> 1
# three  ==> 1
# object  ==> 1
# comparison  ==> 1
# IR  ==> 1
# n  ==> 1
# gram  ==> 1
# phrase  ==> 1
# concept  ==> 1
# ontolog  ==> 1
# labe  ==> 1
# tabl  ==> 1
# nlp  ==> 1
# frequent  ==> 1
# sub  ==> 1
# serv  ==> 1
# ident  ==> 1
# origin  ==> 1
# along  ==> 1
# depend  ==> 1
# IP  ==> 1
# commerci  ==> 1
# signific  ==> 1
# built  ==> 1
# top  ==> 1
# littl  ==> 1
# effort  ==> 1
# key  ==> 1
# abil  ==> 1
# track  ==> 1
# variou  ==> 1
# busi  ==> 1
# new  ==> 1
# turn  ==> 1
# special  ==> 1
# end  ==> 1
# studi  ==> 1
# constraint  ==> 1
# softwar  ==> 1
# advantag  ==> 1
# corpor  ==> 1
# market  ==> 1
# eventu  ==> 1
# volum  ==> 1
# fight  ==> 1
# terror  ==> 1
# predict  ==> 1
# societi  ==> 1
# crimin  ==> 1
# establish  ==> 1
# react  ==> 1
# faster  ==> 1
# save  ==> 1
# product  ==> 1
# cost  ==> 1
# acquir  ==> 1
# insight  ==> 1
# price  ==> 1
# even  ==> 1
# default  ==> 1
# competitor  ==> 1
# promot  ==> 1
# reduc  ==> 1
# risk  ==> 1
# lose  ==> 1
# particularli  ==> 1
# outlin  ==> 1
# framework  ==> 1
# probabilist  ==> 1
# latent  ==> 1
# relev  ==> 1
# collabor  ==> 1
# recommend  ==> 1
# problem  ==> 1
# bias  ==> 1
# question  ==> 1
# regard  ==> 1
# sinc  ==> 1
# subject  ==> 1
# degrad  ==> 1
# element  ==> 1
# uniqu  ==> 1
# phase  ==> 1
# natur  ==> 1
# caus  ==> 1
# critic  ==> 1
# invas  ==> 1
# lost  ==> 1
# dissemin  ==> 1
# especi  ==> 1
# occur  ==> 1
# consent  ==> 1
# form  ==> 1
# mous  ==> 1
# click  ==> 1
# De  ==> 1
# tendenc  ==> 1
# treat  ==> 1
# peopl  ==> 1
# basi  ==> 1
# instead  ==> 1
# total  ==> 1
# violat  ==> 1
# grow  ==> 1
# sell  ==> 1
# commod  ==> 1
# encourag  ==> 1
# owner  ==> 1
# amount  ==> 1
# likeli  ==> 1
# invad  ==> 1
# buy  ==> 1
# oblig  ==> 1
# author  ==> 1
# respons  ==> 1
# inaccuraci  ==> 1
# seriou  ==> 1
# lawsuit  ==> 1
# law  ==> 1
# prevent  ==> 1
# sex  ==> 1
# practic  ==> 1
# anti  ==> 1
# discrimin  ==> 1
# legisl  ==> 1
# hard  ==> 1
# strong  ==> 1
# could  ==> 1
# denial  ==> 1
# privileg  ==> 1
# right  ==> 1
# situat  ==> 1
# avoid  ==> 1
# high  ==> 1
# maintain  ==> 1
# cannot  ==> 1
# trace  ==> 1
# back  ==> 1
# look  ==> 1
# pose  ==> 1
# howev  ==> 1
# separ  ==> 1
# unscrupul  ==> 1
# expans  ==> 1
# ad  ==> 1
# 2015  ==> 1
# theori  ==> 1
# accord  ==> 1
# locat  ==> 1
# describ  ==> 1
# xml  ==> 1
# terminolog  ==> 1
# pagerank  ==> 1
# founder  ==> 1
# larri  ==> 1
# decid  ==> 1
# heterogen  ==> 1
# much  ==> 1
# ever  ==> 1
# lyco  ==> 1
# alta  ==> 1
# vista  ==> 1
# webcrawl  ==> 1
# aliweb  ==> 1
# metacrawl  ==> 1
# comfort  ==> 1
# filter  ==> 1
# factor  ==> 1
# prompt  ==> 1
# well  ==> 1
# extend  ==> 1
# sophist  ==> 1
# AI  ==> 1
# act  ==> 1
# behalf  ==> 1
# differenti  ==> 1
# summar  ==> 1
# done  ==> 1
# isol  ==> 1
# take  ==> 1
# found  ==> 1
# train  ==> 1
# corpu  ==> 1
# insid  ==> 1
# alway  ==> 1
# becom  ==> 1
# sever  ==> 1
# constitut  ==> 1
# whole  ==> 1
# realiz  ==> 1
# To  ==> 1
# resolv  ==> 1
# tf  ==> 1
# idf  ==> 1
# invers  ==> 1
# multi  ==> 1
# scan  ==> 1
# implement  ==> 1
# select  ==> 1
# condit  ==> 1
# rare  ==> 1
# affect  ==> 1
# subset  ==> 1
# function  ==> 1
# set  ==> 1
# gain  ==> 1
# cross  ==> 1
# entropi  ==> 1
# mutual  ==> 1
# odd  ==> 1
# ratio  ==> 1
# classif  ==> 1
# accuraci  ==> 1
# recal  ==> 1
# score  ==> 1
# pipelin  ==> 1
# portal  ==> 1
# confirm  ==> 1
# verif  ==> 1
# build  ==> 1
# opinion  ==> 1
# 10  ==> 1
# complic  ==> 1
# english  ==> 1
# GB  ==> 1
# big5  ==> 1
# HZ  ==> 1
# befor  ==> 1
# analyt  ==> 1
# et  ==> 1
# al  ==> 1
# ngu  ==> 1
# ann  ==> 1
# kitsuregawa  ==> 1
# masaru  ==> 1
# chung  ==> 1
# jen  ==> 1
# yao  ==> 1
# neuhold  ==> 1
# erich  ==> 1
# sheng  ==> 1
# quan  ==> 1
# engin  ==> 1
# wise  ==> 1
# 9783540300175  ==> 1
# bauknecht  ==> 1
# kurt  ==> 1
# madria  ==> 1
# sanjay  ==> 1
# pernul  ==> 1
# gunther  ==> 1
# electron  ==> 1
# first  ==> 1
# EC  ==> 1
# london  ==> 1
# UK  ==> 1
# 165  ==> 1
# 3540679813  ==> 1
# scime  ==> 1
# anthoni  ==> 1
# hershey  ==> 1
# PA  ==> 1
# publish  ==> 1
# 282  ==> 1
# 1591404149  ==> 1
# b  ==> 1
# c  ==> 1
# lita  ==> 1
# van  ==> 1
# wel  ==> 1
# lambèr  ==> 1
# royakk  ==> 1
# kirsten  ==> 1
# wahlstrom  ==> 1
# john  ==> 1
# roddick  ==> 1
# vladimir  ==> 1
# estivil  ==> 1
# castro  ==> 1
# denis  ==> 1
# vri  ==> 1
# yan  ==> 1
# kosala  ==> 1
# raymond  ==> 1
# hendrik  ==> 1
# blockeel  ==> 1
# sigkdd  ==> 1
# arxiv  ==> 1
# cs  ==> 1
# LG  ==> 1
# 0011033  ==> 1
# list  ==> 1
# remain  ==> 1
# unclear  ==> 1
# insuffici  ==> 1
# inlin  ==> 1
# futur  ==> 1
# zdravko  ==> 1
# markov  ==> 1
# laros  ==> 1
# uncov  ==> 1
# wiley  ==> 1
# jesu  ==> 1
# mena  ==> 1
# digit  ==> 1
# soumen  ==> 1
# chakrabarti  ==> 1
# morgan  ==> 1
# kaufmann  ==> 1
# 2002  ==> 1
# advanc  ==> 1
# osmar  ==> 1
# zaian  ==> 1
# myra  ==> 1
# spiliopoul  ==> 1
# philip  ==> 1
# Yu  ==> 1
# lnai  ==> 1
# 4198  ==> 1
# mike  ==> 1
# thelwal  ==> 1
# An  ==> 1
# scienc  ==> 1
# academ  ==> 1
# baraglia  ==> 1
# silvestri  ==> 1
# dynam  ==> 1
# intervent  ==> 1
# 50  ==> 1
# 63  ==> 1
# 67  ==> 1
# srivastav  ==> 1
# 1997  ==> 1
# 9th  ==> 1
# ieee  ==> 1
# prepar  ==> 1
# 32  ==> 1
# RP  ==> 1
# N  ==> 1
# On  ==> 1
# reformul  ==> 1
# 11th  ==> 1
# ibero  ==> 1
# american  ==> 1
# 2008  ==> 1
# octob  ==> 1
# kohavi  ==> 1
# mason  ==> 1
# L  ==> 1
# zheng  ==> 1
# Z  ==> 1
# lesson  ==> 1
# challeng  ==> 1
# retail  ==> 1
# E  ==> 1
# 57  ==> 1
# 83  ==> 1
# 113  ==> 1
# lillian  ==> 1
# clark  ==> 1
# peter  ==> 1
# wright  ==> 1
# ethnograph  ==> 1
# strategi  ==> 1
# 11  ==> 1
# januari  ==> 1
# eirinaki  ==> 1
# vazirgianni  ==> 1
# transact  ==> 1
# februari  ==> 1
# automat  ==> 1
# 43  ==> 1
# 142  ==> 1
# 151  ==> 1
# dai  ==> 1
# luo  ==> 1
# nakagawa  ==> 1
# widm  ==> 1
# atlanta  ==> 1
# GA  ==> 1
# usa  ==> 1
# peten  ==> 1
# proc  ==> 1
# webkdd  ==> 1
# kdd  ==> 1
# premis  ==> 1
# washington  ==> 1
# DC  ==> 1
# 37  ==> 1
# frigui  ==> 1
# joshi  ==> 1
# krishnapuram  ==> 1
# competit  ==> 1
# eighth  ==> 1
# congress  ==> 1
# hsinchu  ==> 1
# taiwan  ==> 1
# invit  ==> 1
# chapter  ==> 1
# wareh  ==> 1
# Ed  ==> 1
# pierrako  ==> 1
# palioura  ==> 1
# papatheodor  ==> 1
# spyropoulo  ==> 1
# 13  ==> 1
# 311  ==> 1
# 372  ==> 1
# miss  ==> 1
# side  ==> 1
# ubb  ==> 1
# unexpect  ==> 1
# behaviour  ==> 1
# design  ==> 1
# P  ==> 1
# owoc  ==> 1
# pleszkun  ==> 1
# 2012  ==> 1
# www  ==> 1
# file  ==> 1
# http  ==> 1
# en  ==> 1
# org  ==> 1
# w  ==> 1
# php  ==> 1
# titl  ==> 1
# web_min  ==> 1
# oldid  ==> 1
# 904363144  ==> 1
# analyticsdata  ==> 1
# miningworld  ==> 1
# webhidden  ==> 1
# cleanupcleanup  ==> 1
# field  ==> 1
# 2009wikipedia  ==> 1
# 2009articl  ==> 1
# 2015all  ==> 1
# expandedarticl  ==> 1
# small  ==> 1
# boxesarticl  ==> 1
# menu  ==> 1
# intalkcontributionscr  ==> 1
# accountlog  ==> 1
# namespac  ==> 1
# articletalk  ==> 1
# variant  ==> 1
# readeditview  ==> 1
# pagecontentsfeatur  ==> 1
# contentcurr  ==> 1
# eventsrandom  ==> 1
# articledon  ==> 1
# wikipediawikipedia  ==> 1
# store  ==> 1
# helpabout  ==> 1
# wikipediacommun  ==> 1
# portalrec  ==> 1
# changescontact  ==> 1
# hererel  ==> 1
# changesupload  ==> 1
# filespeci  ==> 1
# pagesperman  ==> 1
# linkpag  ==> 1
# informationwikidata  ==> 1
# itemcit  ==> 1
# print  ==> 1
# export  ==> 1
# bookdownload  ==> 1
# pdfprintabl  ==> 1
# version  ==> 1
# العربيةdeutschespañoleuskaraفارسیfrançais한국어ह  ==> 1
# न  ==> 1
# द  ==> 1
# hrvatskimagyar日本語portuguêsрусскийslovenčinaไทย  ==> 1
# last  ==> 1
# 2019  ==> 1
# 17  ==> 1
# 30  ==> 1
# utc  ==> 1
# creativ  ==> 1
# sharealik  ==> 1
# licens  ==> 1
# agre  ==> 1
# regist  ==> 1
# trademark  ==> 1
# wikimedia  ==> 1
# foundat  ==> 1
# inc  ==> 1
# non  ==> 1
# disclaim  ==> 1
# contact  ==> 1
# cooki  ==> 1
# statement  ==> 1
# mobil  ==> 1
